# %% [markdown]
# # 1. For Diagonal Co-variance matrix : RWD

# %%
import numpy as np

# Function to compute the determinant of a matrix
def determinant(matrix):
    return np.linalg.det(matrix)

# Function to compute the inverse of a matrix
def inverse(matrix):
    return np.linalg.inv(matrix)

# Function to compute the multivariate Gaussian PDF manually
def multivariate_gaussian(x, mean, cov):
    d = len(x)
    cov_inv = inverse(cov)
    cov_det = determinant(cov)
    norm_factor = 1.0 / (np.power(2 * np.pi, d / 2) * np.sqrt(cov_det))
    x_mu = np.array(x - mean)
    exponent = -0.5 * np.dot(np.dot(x_mu.T, cov_inv), x_mu)
    return norm_factor * np.exp(exponent)

# Load the data from the files
class1_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class1.txt')
class2_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class2.txt')
class3_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class3.txt')

# Split the data into training and test sets (70% train, 30% test)
def train_test_split(data, test_size=0.3, random_state=42):
    np.random.seed(random_state)
    indices = np.random.permutation(len(data))
    split_idx = int(len(data) * (1 - test_size))
    return data[indices[:split_idx]], data[indices[split_idx:]]

train1, test1 = train_test_split(class1_data)
train2, test2 = train_test_split(class2_data)
train3, test3 = train_test_split(class3_data)

# Calculate the mean and covariance for each class
mean1 = np.mean(train1, axis=0)
mean2 = np.mean(train2, axis=0)
mean3 = np.mean(train3, axis=0)

cov1 = np.cov(train1, rowvar=False)
cov2 = np.cov(train2, rowvar=False)
cov3 = np.cov(train3, rowvar=False)

# Average the covariance matrices to get the common covariance matrix
average_cov = (cov1 + cov2 + cov3) / 3
sigma_squared = np.mean([np.var(train1), np.var(train2), np.var(train3)])

# The common covariance matrix (σ^2 * I)
common_cov = sigma_squared * np.identity(average_cov.shape[0])

# Define the class priors (assuming equal priors here)
priors = [1/3, 1/3, 1/3]

# Define a function to compute the posterior probabilities using Bayes' theorem
def bayes_classifier(x, means, cov, priors):
    posteriors = []
    for i, mean in enumerate(means):
        likelihood = multivariate_gaussian(x, mean, cov)
        posterior = likelihood * priors[i]
        posteriors.append(posterior)
    return np.argmax(posteriors)

# Combine the training data and means
train_data = [train1, train2, train3]
means = [mean1, mean2, mean3]

# Testing the classifier
test_data = np.vstack((test1, test2, test3))
true_labels = np.array([0]*len(test1) + [1]*len(test2) + [2]*len(test3))

predicted_labels = [bayes_classifier(x, means, common_cov, priors) for x in test_data]

# Calculate accuracy
accuracy = np.mean(predicted_labels == true_labels)
print(f"Classifier Accuracy: {accuracy * 100:.2f}%")

# Data visualization and decision boundary plotting
# Plot the decision boundary by creating a grid of points
x_min, x_max = test_data[:, 0].min() - 1, test_data[:, 0].max() + 1
y_min, y_max = test_data[:, 1].min() - 1, test_data[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200), np.linspace(y_min, y_max, 200))
grid = np.c_[xx.ravel(), yy.ravel()]

# Predict the class for each point in the grid
grid_predictions = np.array([bayes_classifier(point, means, common_cov, priors) for point in grid])
grid_predictions = grid_predictions.reshape(xx.shape)

# Plotting
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.contourf(xx, yy, grid_predictions, alpha=0.3, cmap='coolwarm')

plt.scatter(train1[:, 0], train1[:, 1], c='blue', label='Class 1', edgecolors='k', marker='o')
plt.scatter(train2[:, 0], train2[:, 1], c='red', label='Class 2', edgecolors='k', marker='s')
plt.scatter(train3[:, 0], train3[:, 1], c='green', label='Class 3', edgecolors='k', marker='^')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Bayes Classifier Decision Boundary')
plt.legend()
plt.show()
# Out:
# Classifier Accuracy: 98.32%

# %% [markdown]
# # 2. for Full Co-variance Matrix : RWD

# %%
import numpy as np

# Function to compute the determinant of a matrix
def determinant(matrix):
    return np.linalg.det(matrix)

# Function to compute the inverse of a matrix
def inverse(matrix):
    return np.linalg.inv(matrix)

# Function to compute the multivariate Gaussian PDF manually
def multivariate_gaussian(x, mean, cov):
    d = len(x)
    cov_inv = inverse(cov)
    cov_det = determinant(cov)
    norm_factor = 1.0 / (np.power(2 * np.pi, d / 2) * np.sqrt(cov_det))
    x_mu = np.array(x - mean)
    exponent = -0.5 * np.dot(np.dot(x_mu.T, cov_inv), x_mu)
    return norm_factor * np.exp(exponent)

# Load the data from the files
class1_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class1.txt')
class2_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class2.txt')
class3_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class3.txt')

# Split the data into training and test sets (70% train, 30% test)
def train_test_split(data, test_size=0.3, random_state=42):
    np.random.seed(random_state)
    indices = np.random.permutation(len(data))
    split_idx = int(len(data) * (1 - test_size))
    return data[indices[:split_idx]], data[indices[split_idx:]]

train1, test1 = train_test_split(class1_data)
train2, test2 = train_test_split(class2_data)
train3, test3 = train_test_split(class3_data)

# Calculate the mean and covariance for each class
mean1 = np.mean(train1, axis=0)
mean2 = np.mean(train2, axis=0)
mean3 = np.mean(train3, axis=0)

cov1 = np.cov(train1, rowvar=False)
cov2 = np.cov(train2, rowvar=False)
cov3 = np.cov(train3, rowvar=False)

# Average the covariance matrices to get the common covariance matrix
common_cov = (cov1 + cov2 + cov3) / 3

# Define the class priors (assuming equal priors here)
priors = [1/3, 1/3, 1/3]

# Define a function to compute the posterior probabilities using Bayes' theorem
def bayes_classifier(x, means, cov, priors):
    posteriors = []
    for i, mean in enumerate(means):
        likelihood = multivariate_gaussian(x, mean, cov)
        posterior = likelihood * priors[i]
        posteriors.append(posterior)
    return np.argmax(posteriors)

# Combine the training data and means
train_data = [train1, train2, train3]
means = [mean1, mean2, mean3]

# Testing the classifier
test_data = np.vstack((test1, test2, test3))
true_labels = np.array([0]*len(test1) + [1]*len(test2) + [2]*len(test3))

predicted_labels = [bayes_classifier(x, means, common_cov, priors) for x in test_data]

# Calculate accuracy
accuracy = np.mean(predicted_labels == true_labels)
print(f"Classifier Accuracy: {accuracy * 100:.2f}%")

# Data visualization and decision boundary plotting
# Plot the decision boundary by creating a grid of points
x_min, x_max = test_data[:, 0].min() - 1, test_data[:, 0].max() + 1
y_min, y_max = test_data[:, 1].min() - 1, test_data[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200), np.linspace(y_min, y_max, 200))
grid = np.c_[xx.ravel(), yy.ravel()]

# Predict the class for each point in the grid
grid_predictions = np.array([bayes_classifier(point, means, common_cov, priors) for point in grid])
grid_predictions = grid_predictions.reshape(xx.shape)

# Plotting
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.contourf(xx, yy, grid_predictions, alpha=0.3, cmap='coolwarm')

plt.scatter(train1[:, 0], train1[:, 1], c='blue', label='Class 1', edgecolors='k', marker='o')
plt.scatter(train2[:, 0], train2[:, 1], c='red', label='Class 2', edgecolors='k', marker='s')
plt.scatter(train3[:, 0], train3[:, 1], c='green', label='Class 3', edgecolors='k', marker='^')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Bayes Classifier Decision Boundary (Full Covariance)')
plt.legend()
plt.show()
# Out:
# Classifier Accuracy: 98.42%

# %% [markdown]
# # 3. for Diaogonal Co-variance Matrix & having different for each classes : RWD

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the files
class1_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class1.txt')
class2_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class2.txt')
class3_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class3.txt')

# Combine the data and create labels
X = np.vstack((class1_data, class2_data, class3_data))
y = np.array([0]*class1_data.shape[0] + [1]*class2_data.shape[0] + [2]*class3_data.shape[0])

# Split the data into training and test sets (70% train, 30% test)
def train_test_split(data, labels, test_size=0.3, random_state=42):
    np.random.seed(random_state)
    indices = np.random.permutation(len(data))
    split_idx = int(len(data) * (1 - test_size))
    return data[indices[:split_idx]], data[indices[split_idx:]], labels[indices[:split_idx]], labels[indices[split_idx:]]

X_train, X_test, y_train, y_test = train_test_split(X, y)

# Compute the mean and covariance matrix for each class
def compute_mean_covariance(X, y):
    classes = np.unique(y)
    means = {}
    covariances = {}
    for c in classes:
        X_c = X[y == c]
        means[c] = np.mean(X_c, axis=0)
        covariances[c] = np.cov(X_c, rowvar=False)
    return means, covariances

means, covariances = compute_mean_covariance(X_train, y_train)

# Define function to calculate multivariate Gaussian PDF manually
def multivariate_gaussian_pdf(x, mean, cov):
    size = len(x)
    det_cov = np.linalg.det(cov)
    inv_cov = np.linalg.inv(cov)
    norm_const = 1.0 / (np.power((2 * np.pi), float(size) / 2) * np.sqrt(det_cov))
    x_mu = np.matrix(x - mean)
    result = np.exp(-0.5 * (x_mu * inv_cov * x_mu.T))
    return norm_const * result

# Define the Bayes classifier manually
def bayes_classifier(X, means, covariances, priors):
    y_pred = []
    for x in X:
        posteriors = []
        for c in means.keys():
            prior = np.log(priors[c])
            likelihood = np.log(multivariate_gaussian_pdf(x, means[c], covariances[c]))
            posterior = prior + likelihood
            posteriors.append(posterior)
        y_pred.append(np.argmax(posteriors))
    return np.array(y_pred)

# Define the priors (assuming equal priors for simplicity)
priors = {0: 1/3, 1: 1/3, 2: 1/3}

# Predict using the manual Bayes classifier
y_pred = bayes_classifier(X_test, means, covariances, priors) 

# Mapping classes to vowels
class_to_vowel = {0: 'e', 1: 'u', 2: 'a'}  # Example mapping

# Identify vowels based on the predictions
vowel_predictions = np.array([class_to_vowel[class_label] for class_label in y_pred])

# Output the predictions
for i in range(len(y_test)):
    print(f"Formants: {X_test[i]}, Predicted Vowel: {vowel_predictions[i]}")

# Calculate accuracy
accuracy = np.mean(y_pred == y_test)
print(f"Classifier Accuracy: {accuracy * 100:.2f}%")

# Plot the decision boundary
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200), np.linspace(y_min, y_max, 200))
grid = np.c_[xx.ravel(), yy.ravel()]

# Predict the class for each point in the grid
Z = bayes_classifier(grid, means, covariances, priors)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(10, 8))
plt.contourf(xx, yy, Z, alpha=0.3, cmap='coolwarm')

plt.scatter(X_train[y_train == 0][:, 0], X_train[y_train == 0][:, 1], c='blue', label='Class 1', edgecolors='k', marker='o')
plt.scatter(X_train[y_train == 1][:, 0], X_train[y_train == 1][:, 1], c='red', label='Class 2', edgecolors='k', marker='s')
plt.scatter(X_train[y_train == 2][:, 0], X_train[y_train == 2][:, 1], c='green', label='Class 3', edgecolors='k', marker='^')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Manual Gaussian Naive Bayes Classifier Decision Boundary')
plt.legend()
plt.show()
# Out:
# Formants: [ 777.34375 1125.     ], Predicted Vowel: a
# Formants: [324.21875 750.     ], Predicted Vowel: u
# Formants: [ 699.21875 1136.71875], Predicted Vowel: a
# Formants: [ 710.9375  1074.21875], Predicted Vowel: a
# Formants: [367.1875 742.1875], Predicted Vowel: u
# Formants: [ 417.96875 2140.625  ], Predicted Vowel: e
# Formants: [339.84375 937.5    ], Predicted Vowel: u
# Formants: [ 765.625   1097.65625], Predicted Vowel: a
# Formants: [343.75  703.125], Predicted Vowel: u
# Formants: [ 710.9375 1078.125 ], Predicted Vowel: a
# Formants: [ 441.40625 2093.75   ], Predicted Vowel: e
# Formants: [ 417.96875 1917.96875], Predicted Vowel: e
# Formants: [410.15625 878.90625], Predicted Vowel: u
# Formants: [ 437.5     2035.15625], Predicted Vowel: e
# Formants: [316.40625 703.125  ], Predicted Vowel: u
# Formants: [ 460.9375  2089.84375], Predicted Vowel: e
# Formants: [ 425.78125 2097.65625], Predicted Vowel: e
# Formants: [ 492.1875  2105.46875], Predicted Vowel: e
# Formants: [351.5625  738.28125], Predicted Vowel: u
# Formants: [433.59375 789.0625 ], Predicted Vowel: u
# Formants: [382.8125 742.1875], Predicted Vowel: u
# Formants: [ 433.59375 2078.125  ], Predicted Vowel: e
# Formants: [ 710.9375  1089.84375], Predicted Vowel: a
# Formants: [ 449.21875 2031.25   ], Predicted Vowel: e
# Formants: [ 457.03125 2089.84375], Predicted Vowel: e
# Formants: [ 363.28125 2058.59375], Predicted Vowel: e
# Formants: [ 468.75   2085.9375], Predicted Vowel: e
# Formants: [308.59375 828.125  ], Predicted Vowel: u
# Formants: [ 656.25 1156.25], Predicted Vowel: a
# Formants: [ 367.1875 2203.125 ], Predicted Vowel: e
# Formants: [ 691.40625 1093.75   ], Predicted Vowel: a
# Formants: [ 433.59375 2039.0625 ], Predicted Vowel: e
# Formants: [ 425.78125 2109.375  ], Predicted Vowel: e
# Formants: [ 718.75  1046.875], Predicted Vowel: a
# Formants: [ 390.625   2128.90625], Predicted Vowel: e
# Formants: [ 453.125 2062.5  ], Predicted Vowel: e
# Formants: [ 777.34375 1089.84375], Predicted Vowel: a
# Formants: [ 363.28125 2097.65625], Predicted Vowel: e
# Formants: [ 414.0625  2089.84375], Predicted Vowel: e
# Formants: [371.09375 617.1875 ], Predicted Vowel: u
# Formants: [347.65625 742.1875 ], Predicted Vowel: u
# Formants: [ 355.46875 2281.25   ], Predicted Vowel: e
# Formants: [ 699.21875 1105.46875], Predicted Vowel: a
# Formants: [371.09375 753.90625], Predicted Vowel: u
# Formants: [367.1875 750.    ], Predicted Vowel: u
# Formants: [ 308.59375 2058.59375], Predicted Vowel: e
# Formants: [ 468.75   2023.4375], Predicted Vowel: e
# Formants: [304.6875  832.03125], Predicted Vowel: u
# Formants: [ 421.875   2035.15625], Predicted Vowel: e
# Formants: [ 773.4375 1101.5625], Predicted Vowel: a
# Formants: [ 707.03125 1085.9375 ], Predicted Vowel: a
# Formants: [ 394.53125 2234.375  ], Predicted Vowel: e
# Formants: [414.0625 734.375 ], Predicted Vowel: u
# Formants: [ 425.78125 2039.0625 ], Predicted Vowel: e
# Formants: [ 421.875   2121.09375], Predicted Vowel: e
# Formants: [ 742.1875  1191.40625], Predicted Vowel: a
# Formants: [351.5625  707.03125], Predicted Vowel: u
# Formants: [343.75    714.84375], Predicted Vowel: u
# Formants: [ 742.1875 1101.5625], Predicted Vowel: a
# Formants: [441.40625 769.53125], Predicted Vowel: u
# Formants: [328.125   683.59375], Predicted Vowel: u
# Formants: [ 695.3125 1140.625 ], Predicted Vowel: a
# Formants: [ 402.34375 2214.84375], Predicted Vowel: e
# Formants: [332.03125 750.     ], Predicted Vowel: u
# Formants: [ 750.      1113.28125], Predicted Vowel: a
# Formants: [ 398.4375 2257.8125], Predicted Vowel: e
# Formants: [ 390.625 2281.25 ], Predicted Vowel: e
# Formants: [ 402.34375 2199.21875], Predicted Vowel: e
# Formants: [363.28125 699.21875], Predicted Vowel: u
# Formants: [ 695.3125 1031.25  ], Predicted Vowel: a
# Formants: [367.1875 742.1875], Predicted Vowel: u
# Formants: [371.09375 746.09375], Predicted Vowel: u
# Formants: [ 406.25    1941.40625], Predicted Vowel: e
# Formants: [ 746.09375 1195.3125 ], Predicted Vowel: a
# Formants: [ 683.59375 1121.09375], Predicted Vowel: a
# Formants: [324.21875 792.96875], Predicted Vowel: u
# Formants: [ 339.84375 1910.15625], Predicted Vowel: e
# Formants: [ 722.65625 1070.3125 ], Predicted Vowel: a
# Formants: [308.59375 750.     ], Predicted Vowel: u
# Formants: [ 449.21875 2105.46875], Predicted Vowel: e
# Formants: [328.125   753.90625], Predicted Vowel: u
# Formants: [332.03125 660.15625], Predicted Vowel: u
# Formants: [347.65625 703.125  ], Predicted Vowel: u
# Formants: [304.6875 632.8125], Predicted Vowel: u
# Formants: [328.125   722.65625], Predicted Vowel: u
# Formants: [ 421.875   2050.78125], Predicted Vowel: e
# Formants: [ 714.84375 1144.53125], Predicted Vowel: a
# Formants: [ 734.375   1058.59375], Predicted Vowel: a
# Formants: [ 476.5625  2089.84375], Predicted Vowel: e
# Formants: [ 761.71875 1121.09375], Predicted Vowel: a
# Formants: [332.03125 707.03125], Predicted Vowel: u
# Formants: [ 402.34375 2226.5625 ], Predicted Vowel: e
# Formants: [332.03125 722.65625], Predicted Vowel: u
# Formants: [ 761.71875 1144.53125], Predicted Vowel: a
# Formants: [ 707.03125 1066.40625], Predicted Vowel: a
# Formants: [ 796.875 1125.   ], Predicted Vowel: a
# Formants: [355.46875 777.34375], Predicted Vowel: u
# Formants: [ 429.6875  2066.40625], Predicted Vowel: e
# Formants: [375.   843.75], Predicted Vowel: u
# Formants: [320.3125 710.9375], Predicted Vowel: u
# Formants: [ 433.59375 2046.875  ], Predicted Vowel: e
# Formants: [355.46875 718.75   ], Predicted Vowel: u
# Formants: [ 441.40625 2062.5    ], Predicted Vowel: e
# Formants: [ 699.21875 1152.34375], Predicted Vowel: a
# Formants: [ 386.71875 1000.     ], Predicted Vowel: u
# Formants: [312.5     738.28125], Predicted Vowel: u
# Formants: [ 429.6875  2144.53125], Predicted Vowel: e
# Formants: [332.03125 707.03125], Predicted Vowel: u
# Formants: [ 398.4375  2136.71875], Predicted Vowel: e
# Formants: [ 753.90625 1285.15625], Predicted Vowel: a
# Formants: [ 703.125   1082.03125], Predicted Vowel: a
# Formants: [363.28125 742.1875 ], Predicted Vowel: u
# Formants: [ 437.5     2050.78125], Predicted Vowel: e
# Formants: [328.125 687.5  ], Predicted Vowel: u
# Formants: [ 425.78125 2023.4375 ], Predicted Vowel: e
# Formants: [ 484.375 2093.75 ], Predicted Vowel: e
# Formants: [ 757.8125  1105.46875], Predicted Vowel: a
# Formants: [ 792.96875 1121.09375], Predicted Vowel: a
# Formants: [ 718.75    1066.40625], Predicted Vowel: a
# Formants: [ 738.28125 1085.9375 ], Predicted Vowel: a
# Formants: [ 367.1875  1972.65625], Predicted Vowel: e
# Formants: [ 277.34375 2250.     ], Predicted Vowel: e
# Formants: [ 679.6875 1148.4375], Predicted Vowel: a
# Formants: [ 375.      2277.34375], Predicted Vowel: e
# Formants: [ 425.78125 2007.8125 ], Predicted Vowel: e
# Formants: [339.84375 664.0625 ], Predicted Vowel: u
# Formants: [ 496.09375 2089.84375], Predicted Vowel: e
# Formants: [ 429.6875  2035.15625], Predicted Vowel: e
# Formants: [ 996.09375 1000.     ], Predicted Vowel: a
# Formants: [378.90625 722.65625], Predicted Vowel: u
# Formants: [ 472.65625 2074.21875], Predicted Vowel: e
# Formants: [339.84375 824.21875], Predicted Vowel: u
# Formants: [ 191.40625 1015.625  ], Predicted Vowel: u
# Formants: [457.03125 863.28125], Predicted Vowel: u
# Formants: [ 417.96875 2000.     ], Predicted Vowel: e
# Formants: [339.84375 703.125  ], Predicted Vowel: u
# Formants: [ 433.59375 2121.09375], Predicted Vowel: e
# Formants: [ 417.96875 2226.5625 ], Predicted Vowel: e
# Formants: [367.1875 781.25  ], Predicted Vowel: u
# Formants: [ 398.4375 1992.1875], Predicted Vowel: e
# Formants: [363.28125 718.75   ], Predicted Vowel: u
# Formants: [ 917.96875 1500.     ], Predicted Vowel: a
# Formants: [343.75    753.90625], Predicted Vowel: u
# Formants: [390.625   769.53125], Predicted Vowel: u
# Formants: [378.90625 734.375  ], Predicted Vowel: u
# Formants: [ 363.28125 2210.9375 ], Predicted Vowel: e
# Formants: [ 746.09375 1101.5625 ], Predicted Vowel: a
# Formants: [386.71875 765.625  ], Predicted Vowel: u
# Formants: [ 468.75    2074.21875], Predicted Vowel: e
# Formants: [359.375   769.53125], Predicted Vowel: u
# Formants: [ 699.21875 1109.375  ], Predicted Vowel: a
# Formants: [ 437.5   2046.875], Predicted Vowel: e
# Formants: [ 683.59375 1121.09375], Predicted Vowel: a
# Formants: [343.75    722.65625], Predicted Vowel: u
# Formants: [355.46875 730.46875], Predicted Vowel: u
# Formants: [ 406.25 2250.  ], Predicted Vowel: e
# Formants: [363.28125 722.65625], Predicted Vowel: u
# Formants: [ 695.3125  1066.40625], Predicted Vowel: a
# Formants: [ 695.3125  1082.03125], Predicted Vowel: a
# Formants: [ 371.09375 2066.40625], Predicted Vowel: e
# Formants: [ 781.25    1121.09375], Predicted Vowel: a
# Formants: [ 402.34375 1992.1875 ], Predicted Vowel: e
# Formants: [ 753.90625 1035.15625], Predicted Vowel: a
# Formants: [ 691.40625 1113.28125], Predicted Vowel: a
# Formants: [167.96875 937.5    ], Predicted Vowel: u
# Formants: [ 687.5   1140.625], Predicted Vowel: a
# Formants: [ 394.53125 2027.34375], Predicted Vowel: e
# Formants: [ 457.03125 2015.625  ], Predicted Vowel: e
# Formants: [ 421.875 2234.375], Predicted Vowel: e
# Formants: [367.1875  808.59375], Predicted Vowel: u
# Formants: [ 433.59375 2042.96875], Predicted Vowel: e
# Formants: [ 718.75    1089.84375], Predicted Vowel: a
# Formants: [ 496.09375 2066.40625], Predicted Vowel: e
# Formants: [ 742.1875 1109.375 ], Predicted Vowel: a
# Formants: [ 425.78125 2023.4375 ], Predicted Vowel: e
# Formants: [367.1875 710.9375], Predicted Vowel: u
# Formants: [ 464.84375 2085.9375 ], Predicted Vowel: e
# Formants: [ 449.21875 2042.96875], Predicted Vowel: e
# Formants: [ 375.      2144.53125], Predicted Vowel: e
# Formants: [ 363.28125 1894.53125], Predicted Vowel: e
# Formants: [406.25    714.84375], Predicted Vowel: u
# Formants: [ 750.      1152.34375], Predicted Vowel: a
# Formants: [ 375.     2210.9375], Predicted Vowel: e
# Formants: [ 433.59375 2132.8125 ], Predicted Vowel: e
# Formants: [ 421.875   2003.90625], Predicted Vowel: e
# Formants: [ 746.09375 1082.03125], Predicted Vowel: a
# Formants: [ 429.6875 2000.    ], Predicted Vowel: e
# Formants: [ 742.1875  1214.84375], Predicted Vowel: a
# Formants: [ 390.625   2246.09375], Predicted Vowel: e
# Formants: [355.46875 703.125  ], Predicted Vowel: u
# Formants: [375.     664.0625], Predicted Vowel: u
# Formants: [ 425.78125 2289.0625 ], Predicted Vowel: e
# Formants: [ 433.59375 2000.     ], Predicted Vowel: e
# Formants: [ 394.53125 2246.09375], Predicted Vowel: e
# Formants: [ 390.625  2242.1875], Predicted Vowel: e
# Formants: [375.     757.8125], Predicted Vowel: u
# Formants: [ 757.8125 1289.0625], Predicted Vowel: a
# Formants: [ 371.09375 2179.6875 ], Predicted Vowel: e
# Formants: [332.03125 691.40625], Predicted Vowel: u
# Formants: [382.8125 867.1875], Predicted Vowel: u
# Formants: [ 269.53125 2265.625  ], Predicted Vowel: e
# Formants: [304.6875  785.15625], Predicted Vowel: u
# Formants: [ 472.65625 2089.84375], Predicted Vowel: e
# Formants: [ 718.75    1074.21875], Predicted Vowel: a
# Formants: [367.1875  863.28125], Predicted Vowel: u
# Formants: [ 468.75   2039.0625], Predicted Vowel: e
# Formants: [ 785.15625 1156.25   ], Predicted Vowel: a
# Formants: [320.3125  699.21875], Predicted Vowel: u
# Formants: [398.4375  785.15625], Predicted Vowel: u
# Formants: [ 343.75    2097.65625], Predicted Vowel: e
# Formants: [ 777.34375 1109.375  ], Predicted Vowel: a
# Formants: [ 414.0625 2015.625 ], Predicted Vowel: e
# Formants: [ 503.90625 2070.3125 ], Predicted Vowel: e
# Formants: [355.46875 714.84375], Predicted Vowel: u
# Formants: [ 746.09375 1109.375  ], Predicted Vowel: a
# Formants: [ 421.875   2175.78125], Predicted Vowel: e
# Formants: [ 699.21875 1046.875  ], Predicted Vowel: a
# Formants: [ 281.25    2121.09375], Predicted Vowel: e
# Formants: [ 417.96875 2023.4375 ], Predicted Vowel: e
# Formants: [332.03125 695.3125 ], Predicted Vowel: u
# Formants: [ 515.625 1000.   ], Predicted Vowel: a
# Formants: [ 769.53125 1210.9375 ], Predicted Vowel: a
# Formants: [ 687.5     1136.71875], Predicted Vowel: a
# Formants: [ 402.34375 2218.75   ], Predicted Vowel: e
# Formants: [ 429.6875  2042.96875], Predicted Vowel: e
# Formants: [351.5625 906.25  ], Predicted Vowel: u
# Formants: [332.03125 683.59375], Predicted Vowel: u
# Formants: [ 789.0625 1117.1875], Predicted Vowel: a
# Formants: [359.375  679.6875], Predicted Vowel: u
# Formants: [ 492.1875  1910.15625], Predicted Vowel: e
# Formants: [ 476.5625  2027.34375], Predicted Vowel: e
# Formants: [ 703.125  1117.1875], Predicted Vowel: a
# Formants: [ 699.21875 1109.375  ], Predicted Vowel: a
# Formants: [ 765.625   1128.90625], Predicted Vowel: a
# Formants: [ 414.0625 2070.3125], Predicted Vowel: e
# Formants: [ 421.875 2125.   ], Predicted Vowel: e
# Formants: [269.53125 789.0625 ], Predicted Vowel: u
# Formants: [363.28125 695.3125 ], Predicted Vowel: u
# Formants: [359.375   769.53125], Predicted Vowel: u
# Formants: [ 390.625   2253.90625], Predicted Vowel: e
# Formants: [363.28125 742.1875 ], Predicted Vowel: u
# Formants: [ 421.875   2050.78125], Predicted Vowel: e
# Formants: [320.3125  691.40625], Predicted Vowel: u
# Formants: [339.84375 691.40625], Predicted Vowel: u
# Formants: [363.28125 699.21875], Predicted Vowel: u
# Formants: [ 488.28125 2074.21875], Predicted Vowel: e
# Formants: [ 722.65625 1121.09375], Predicted Vowel: a
# Formants: [308.59375 746.09375], Predicted Vowel: u
# Formants: [367.1875  769.53125], Predicted Vowel: u
# Formants: [ 437.5    2085.9375], Predicted Vowel: e
# Formants: [ 472.65625 2039.0625 ], Predicted Vowel: e
# Formants: [ 414.0625 2070.3125], Predicted Vowel: e
# Formants: [359.375  757.8125], Predicted Vowel: u
# Formants: [375.     789.0625], Predicted Vowel: u
# Formants: [ 781.25    1160.15625], Predicted Vowel: a
# Formants: [ 417.96875 2078.125  ], Predicted Vowel: e
# Formants: [343.75    761.71875], Predicted Vowel: u
# Formants: [ 406.25 1156.25], Predicted Vowel: a
# Formants: [ 437.5     2136.71875], Predicted Vowel: e
# Formants: [ 519.53125 2070.3125 ], Predicted Vowel: e
# Formants: [ 527.34375 2066.40625], Predicted Vowel: e
# Formants: [ 781.25    1144.53125], Predicted Vowel: a
# Formants: [ 433.59375 2046.875  ], Predicted Vowel: e
# Formants: [ 363.28125 2257.8125 ], Predicted Vowel: e
# Formants: [363.28125 742.1875 ], Predicted Vowel: u
# Formants: [371.09375 730.46875], Predicted Vowel: u
# Formants: [ 476.5625  2097.65625], Predicted Vowel: e
# Formants: [359.375   699.21875], Predicted Vowel: u
# Formants: [ 746.09375 1246.09375], Predicted Vowel: a
# Formants: [ 738.28125 1058.59375], Predicted Vowel: a
# Formants: [355.46875 679.6875 ], Predicted Vowel: u
# Formants: [328.125  679.6875], Predicted Vowel: u
# Formants: [ 726.5625 1023.4375], Predicted Vowel: a
# Formants: [363.28125 714.84375], Predicted Vowel: u
# Formants: [ 488.28125 2101.5625 ], Predicted Vowel: e
# Formants: [ 773.4375 1117.1875], Predicted Vowel: a
# Formants: [351.5625 718.75  ], Predicted Vowel: u
# Formants: [ 726.5625  1089.84375], Predicted Vowel: a
# Formants: [ 394.53125 1000.     ], Predicted Vowel: u
# Formants: [ 773.4375 1117.1875], Predicted Vowel: a
# Formants: [371.09375 695.3125 ], Predicted Vowel: u
# Formants: [328.125   730.46875], Predicted Vowel: u
# Formants: [ 718.75   1164.0625], Predicted Vowel: a
# Formants: [371.09375 750.     ], Predicted Vowel: u
# Formants: [ 781.25    1152.34375], Predicted Vowel: a
# Formants: [ 488.28125 2074.21875], Predicted Vowel: e
# Formants: [ 769.53125 1109.375  ], Predicted Vowel: a
# Formants: [378.90625 867.1875 ], Predicted Vowel: u
# Formants: [ 484.375   2082.03125], Predicted Vowel: e
# Formants: [ 730.46875 1171.875  ], Predicted Vowel: a
# Formants: [ 761.71875 1125.     ], Predicted Vowel: a
# Formants: [ 378.90625 2070.3125 ], Predicted Vowel: e
# Formants: [ 781.25  1078.125], Predicted Vowel: a
# Formants: [ 707.03125 1152.34375], Predicted Vowel: a
# Formants: [ 417.96875 2148.4375 ], Predicted Vowel: e
# Formants: [367.1875  722.65625], Predicted Vowel: u
# Formants: [343.75    761.71875], Predicted Vowel: u
# Formants: [304.6875  730.46875], Predicted Vowel: u
# Formants: [410.15625 812.5    ], Predicted Vowel: u
# Formants: [343.75    722.65625], Predicted Vowel: u
# Formants: [ 433.59375 1000.     ], Predicted Vowel: u
# Formants: [ 691.40625 1144.53125], Predicted Vowel: a
# Formants: [ 503.90625 2093.75   ], Predicted Vowel: e
# Formants: [ 386.71875 2281.25   ], Predicted Vowel: e
# Formants: [ 710.9375  1074.21875], Predicted Vowel: a
# Formants: [406.25    808.59375], Predicted Vowel: u
# Formants: [363.28125 812.5    ], Predicted Vowel: u
# Formants: [ 707.03125 1121.09375], Predicted Vowel: a
# Formants: [ 464.84375 2070.3125 ], Predicted Vowel: e
# Formants: [339.84375 679.6875 ], Predicted Vowel: u
# Formants: [ 738.28125 1117.1875 ], Predicted Vowel: a
# Formants: [ 441.40625 2011.71875], Predicted Vowel: e
# Formants: [ 476.5625 2125.    ], Predicted Vowel: e
# Formants: [335.9375 773.4375], Predicted Vowel: u
# Formants: [351.5625 742.1875], Predicted Vowel: u
# Formants: [ 781.25    1152.34375], Predicted Vowel: a
# Formants: [ 714.84375 1062.5    ], Predicted Vowel: a
# Formants: [ 378.90625 1898.4375 ], Predicted Vowel: e
# Formants: [406.25   867.1875], Predicted Vowel: u
# Formants: [ 496.09375 2085.9375 ], Predicted Vowel: e
# Formants: [ 464.84375 2082.03125], Predicted Vowel: e
# Formants: [ 457.03125 2089.84375], Predicted Vowel: e
# Formants: [ 789.0625 1140.625 ], Predicted Vowel: a
# Formants: [ 437.5     2050.78125], Predicted Vowel: e
# Formants: [328.125  710.9375], Predicted Vowel: u
# Formants: [ 710.9375  1097.65625], Predicted Vowel: a
# Formants: [ 445.3125 2031.25  ], Predicted Vowel: e
# Formants: [ 726.5625 1187.5   ], Predicted Vowel: a
# Formants: [ 347.65625 2265.625  ], Predicted Vowel: e
# Formants: [ 429.6875  2089.84375], Predicted Vowel: e
# Formants: [367.1875 750.    ], Predicted Vowel: u
# Formants: [ 464.84375 2027.34375], Predicted Vowel: e
# Formants: [ 335.9375  2144.53125], Predicted Vowel: e
# Formants: [375.      707.03125], Predicted Vowel: u
# Formants: [ 722.65625 1203.125  ], Predicted Vowel: a
# Formants: [ 433.59375 2082.03125], Predicted Vowel: e
# Formants: [ 480.46875 1000.     ], Predicted Vowel: u
# Formants: [363.28125 722.65625], Predicted Vowel: u
# Formants: [414.0625  800.78125], Predicted Vowel: u
# Formants: [ 484.375   2097.65625], Predicted Vowel: e
# Formants: [300.78125 773.4375 ], Predicted Vowel: u
# Formants: [335.9375 664.0625], Predicted Vowel: u
# Formants: [ 593.75    1191.40625], Predicted Vowel: a
# Formants: [ 726.5625  1082.03125], Predicted Vowel: a
# Formants: [ 363.28125 2128.90625], Predicted Vowel: e
# Formants: [ 753.90625 1132.8125 ], Predicted Vowel: a
# Formants: [ 445.3125 2023.4375], Predicted Vowel: e
# Formants: [218.75    785.15625], Predicted Vowel: u
# Formants: [ 421.875   2238.28125], Predicted Vowel: e
# Formants: [ 371.09375 2011.71875], Predicted Vowel: e
# Formants: [ 441.40625 2109.375  ], Predicted Vowel: e
# Formants: [ 402.34375 2226.5625 ], Predicted Vowel: e
# Formants: [ 472.65625 2035.15625], Predicted Vowel: e
# Formants: [359.375   746.09375], Predicted Vowel: u
# Formants: [312.5     683.59375], Predicted Vowel: u
# Formants: [ 402.34375 2246.09375], Predicted Vowel: e
# Formants: [242.1875 929.6875], Predicted Vowel: u
# Formants: [ 742.1875 1101.5625], Predicted Vowel: a
# Formants: [324.21875 683.59375], Predicted Vowel: u
# Formants: [355.46875 722.65625], Predicted Vowel: u
# Formants: [363.28125 859.375  ], Predicted Vowel: u
# Formants: [343.75   695.3125], Predicted Vowel: u
# Formants: [ 742.1875 1226.5625], Predicted Vowel: a
# Formants: [ 710.9375 1085.9375], Predicted Vowel: a
# Formants: [ 707.03125 1082.03125], Predicted Vowel: a
# Formants: [ 453.125   2042.96875], Predicted Vowel: e
# Formants: [ 757.8125 1140.625 ], Predicted Vowel: a
# Formants: [402.34375 800.78125], Predicted Vowel: u
# Formants: [320.3125  722.65625], Predicted Vowel: u
# Formants: [355.46875 730.46875], Predicted Vowel: u
# Formants: [ 781.25 1156.25], Predicted Vowel: a
# Formants: [ 410.15625 2027.34375], Predicted Vowel: e
# Formants: [343.75    738.28125], Predicted Vowel: u
# Formants: [ 773.4375  1136.71875], Predicted Vowel: a
# Formants: [ 421.875  2023.4375], Predicted Vowel: e
# Formants: [ 406.25   2242.1875], Predicted Vowel: e
# Formants: [363.28125 738.28125], Predicted Vowel: u
# Formants: [ 738.28125 1000.     ], Predicted Vowel: a
# Formants: [343.75   742.1875], Predicted Vowel: u
# Formants: [ 421.875   2011.71875], Predicted Vowel: e
# Formants: [ 710.9375 1078.125 ], Predicted Vowel: a
# Formants: [ 781.25 1125.  ], Predicted Vowel: a
# Formants: [367.1875  699.21875], Predicted Vowel: u
# Formants: [ 734.375   1175.78125], Predicted Vowel: a
# Formants: [ 410.15625 2078.125  ], Predicted Vowel: e
# Formants: [ 726.5625 1054.6875], Predicted Vowel: a
# Formants: [ 390.625   2222.65625], Predicted Vowel: e
# Formants: [386.71875 714.84375], Predicted Vowel: u
# Formants: [ 414.0625  2003.90625], Predicted Vowel: e
# Formants: [ 796.875   1058.59375], Predicted Vowel: a
# Formants: [343.75    761.71875], Predicted Vowel: u
# Formants: [ 730.46875 1156.25   ], Predicted Vowel: a
# Formants: [ 789.0625  1121.09375], Predicted Vowel: a
# Formants: [ 765.625 1093.75 ], Predicted Vowel: a
# Formants: [332.03125 695.3125 ], Predicted Vowel: u
# Formants: [ 500.      2058.59375], Predicted Vowel: e
# Formants: [449.21875 792.96875], Predicted Vowel: u
# Formants: [ 441.40625 2007.8125 ], Predicted Vowel: e
# Formants: [363.28125 761.71875], Predicted Vowel: u
# Formants: [ 390.625   2269.53125], Predicted Vowel: e
# Formants: [308.59375 660.15625], Predicted Vowel: u
# Formants: [ 464.84375 2062.5    ], Predicted Vowel: e
# Formants: [367.1875 703.125 ], Predicted Vowel: u
# Formants: [339.84375 726.5625 ], Predicted Vowel: u
# Formants: [ 464.84375 2089.84375], Predicted Vowel: e
# Formants: [ 476.5625 2093.75  ], Predicted Vowel: e
# Formants: [ 773.4375 1117.1875], Predicted Vowel: a
# Formants: [ 433.59375 2015.625  ], Predicted Vowel: e
# Formants: [ 441.40625 2117.1875 ], Predicted Vowel: e
# Formants: [335.9375 750.    ], Predicted Vowel: u
# Formants: [ 718.75  1109.375], Predicted Vowel: a
# Formants: [367.1875 710.9375], Predicted Vowel: u
# Formants: [ 445.3125 2046.875 ], Predicted Vowel: e
# Formants: [ 750.     1085.9375], Predicted Vowel: a
# Formants: [ 691.40625 1140.625  ], Predicted Vowel: a
# Formants: [ 476.5625  2089.84375], Predicted Vowel: e
# Formants: [441.40625 796.875  ], Predicted Vowel: u
# Formants: [ 710.9375  1136.71875], Predicted Vowel: a
# Formants: [ 437.5     2089.84375], Predicted Vowel: e
# Formants: [ 460.9375 2000.    ], Predicted Vowel: e
# Formants: [386.71875 796.875  ], Predicted Vowel: u
# Formants: [ 464.84375 2054.6875 ], Predicted Vowel: e
# Formants: [ 363.28125 2214.84375], Predicted Vowel: e
# Formants: [300.78125 656.25   ], Predicted Vowel: u
# Formants: [ 816.40625 1117.1875 ], Predicted Vowel: a
# Formants: [363.28125 679.6875 ], Predicted Vowel: u
# Formants: [ 394.53125 2195.3125 ], Predicted Vowel: e
# Formants: [ 453.125   2066.40625], Predicted Vowel: e
# Formants: [ 699.21875 1164.0625 ], Predicted Vowel: a
# Formants: [347.65625 718.75   ], Predicted Vowel: u
# Formants: [382.8125 671.875 ], Predicted Vowel: u
# Formants: [ 257.8125  2261.71875], Predicted Vowel: e
# Formants: [ 398.4375 2242.1875], Predicted Vowel: e
# Formants: [ 472.65625 2105.46875], Predicted Vowel: e
# Formants: [406.25    871.09375], Predicted Vowel: u
# Formants: [410.15625 789.0625 ], Predicted Vowel: u
# Formants: [ 355.46875 2261.71875], Predicted Vowel: e
# Formants: [ 398.4375 2093.75  ], Predicted Vowel: e
# Formants: [ 359.375   2261.71875], Predicted Vowel: e
# Formants: [ 742.1875  1191.40625], Predicted Vowel: a
# Formants: [378.90625 769.53125], Predicted Vowel: u
# Formants: [410.15625 863.28125], Predicted Vowel: u
# Formants: [ 472.65625 2082.03125], Predicted Vowel: e
# Formants: [ 398.4375 2242.1875], Predicted Vowel: e
# Formants: [ 429.6875 2140.625 ], Predicted Vowel: e
# Formants: [363.28125 718.75   ], Predicted Vowel: u
# Formants: [414.0625 812.5   ], Predicted Vowel: u
# Formants: [437.5     902.34375], Predicted Vowel: u
# Formants: [ 480.46875 2089.84375], Predicted Vowel: e
# Formants: [ 730.46875 1078.125  ], Predicted Vowel: a
# Formants: [ 421.875  2101.5625], Predicted Vowel: e
# Formants: [328.125  742.1875], Predicted Vowel: u
# Formants: [367.1875  761.71875], Predicted Vowel: u
# Formants: [ 449.21875 2058.59375], Predicted Vowel: e
# Formants: [ 378.90625 1000.     ], Predicted Vowel: u
# Formants: [ 453.125   2074.21875], Predicted Vowel: e
# Formants: [ 691.40625 1148.4375 ], Predicted Vowel: a
# Formants: [ 421.875 2046.875], Predicted Vowel: e
# Formants: [ 753.90625 1289.0625 ], Predicted Vowel: a
# Formants: [ 328.125 1906.25 ], Predicted Vowel: e
# Formants: [367.1875 750.    ], Predicted Vowel: u
# Formants: [ 421.875   2152.34375], Predicted Vowel: e
# Formants: [ 562.5     2027.34375], Predicted Vowel: e
# Formants: [ 773.4375  1121.09375], Predicted Vowel: a
# Formants: [ 750.     1117.1875], Predicted Vowel: a
# Formants: [343.75    714.84375], Predicted Vowel: u
# Formants: [ 398.4375 2250.    ], Predicted Vowel: e
# Formants: [ 734.375   1050.78125], Predicted Vowel: a
# Formants: [ 707.03125 1125.     ], Predicted Vowel: a
# Formants: [ 386.71875 2250.     ], Predicted Vowel: e
# Formants: [ 457.03125 2085.9375 ], Predicted Vowel: e
# Formants: [324.21875 691.40625], Predicted Vowel: u
# Formants: [382.8125  753.90625], Predicted Vowel: u
# Formants: [ 460.9375 2070.3125], Predicted Vowel: e
# Formants: [ 421.875   2019.53125], Predicted Vowel: e
# Formants: [355.46875 695.3125 ], Predicted Vowel: u
# Formants: [ 425.78125 1968.75   ], Predicted Vowel: e
# Formants: [ 390.625 2203.125], Predicted Vowel: e
# Formants: [ 773.4375  1121.09375], Predicted Vowel: a
# Formants: [ 402.34375 2125.     ], Predicted Vowel: e
# Formants: [351.5625 718.75  ], Predicted Vowel: u
# Formants: [ 394.53125 2207.03125], Predicted Vowel: e
# Formants: [335.9375 671.875 ], Predicted Vowel: u
# Formants: [398.4375 734.375 ], Predicted Vowel: u
# Formants: [363.28125 652.34375], Predicted Vowel: u
# Formants: [ 636.71875 1000.     ], Predicted Vowel: a
# Formants: [ 765.625  1085.9375], Predicted Vowel: a
# Formants: [ 761.71875 1125.     ], Predicted Vowel: a
# Formants: [332.03125 777.34375], Predicted Vowel: u
# Formants: [359.375   824.21875], Predicted Vowel: u
# Formants: [ 433.59375 2054.6875 ], Predicted Vowel: e
# Formants: [ 429.6875  2128.90625], Predicted Vowel: e
# Formants: [363.28125 722.65625], Predicted Vowel: u
# Formants: [ 441.40625 2042.96875], Predicted Vowel: e
# Formants: [ 769.53125 1109.375  ], Predicted Vowel: a
# Formants: [ 699.21875 1117.1875 ], Predicted Vowel: a
# Formants: [ 433.59375 2035.15625], Predicted Vowel: e
# Formants: [ 761.71875 1089.84375], Predicted Vowel: a
# Formants: [316.40625 695.3125 ], Predicted Vowel: u
# Formants: [ 406.25    2199.21875], Predicted Vowel: e
# Formants: [683.59375 996.09375], Predicted Vowel: a
# Formants: [ 710.9375  1003.90625], Predicted Vowel: a
# Formants: [ 468.75   2101.5625], Predicted Vowel: e
# Formants: [363.28125 742.1875 ], Predicted Vowel: u
# Formants: [ 781.25   1117.1875], Predicted Vowel: a
# Formants: [ 441.40625 2148.4375 ], Predicted Vowel: e
# Formants: [ 707.03125 1050.78125], Predicted Vowel: a
# Formants: [347.65625 769.53125], Predicted Vowel: u
# Formants: [406.25  796.875], Predicted Vowel: u
# Formants: [ 453.125   2050.78125], Predicted Vowel: e
# Formants: [363.28125 738.28125], Predicted Vowel: u
# Formants: [ 457.03125 2074.21875], Predicted Vowel: e
# Formants: [ 406.25    1996.09375], Predicted Vowel: e
# Formants: [363.28125 722.65625], Predicted Vowel: u
# Formants: [ 484.375   2042.96875], Predicted Vowel: e
# Formants: [ 859.375   1199.21875], Predicted Vowel: a
# Formants: [359.375   722.65625], Predicted Vowel: u
# Formants: [410.15625 828.125  ], Predicted Vowel: u
# Formants: [ 457.03125 2070.3125 ], Predicted Vowel: e
# Formants: [339.84375 710.9375 ], Predicted Vowel: u
# Formants: [363.28125 699.21875], Predicted Vowel: u
# Formants: [ 402.34375 2269.53125], Predicted Vowel: e
# Formants: [343.75    691.40625], Predicted Vowel: u
# Formants: [363.28125 714.84375], Predicted Vowel: u
# Formants: [375.     945.3125], Predicted Vowel: u
# Formants: [ 730.46875 1238.28125], Predicted Vowel: a
# Formants: [ 683.59375 1113.28125], Predicted Vowel: a
# Formants: [ 710.9375  1175.78125], Predicted Vowel: a
# Formants: [398.4375  761.71875], Predicted Vowel: u
# Formants: [367.1875 742.1875], Predicted Vowel: u
# Formants: [ 410.15625 2125.     ], Predicted Vowel: e
# Formants: [ 468.75    1980.46875], Predicted Vowel: e
# Formants: [ 687.5     1113.28125], Predicted Vowel: a
# Formants: [ 460.9375  2136.71875], Predicted Vowel: e
# Formants: [343.75  671.875], Predicted Vowel: u
# Formants: [355.46875 703.125  ], Predicted Vowel: u
# Formants: [ 476.5625  2089.84375], Predicted Vowel: e
# Formants: [363.28125 843.75   ], Predicted Vowel: u
# Formants: [ 722.65625 1195.3125 ], Predicted Vowel: a
# Formants: [ 707.03125 1050.78125], Predicted Vowel: a
# Formants: [ 781.25    1128.90625], Predicted Vowel: a
# Formants: [ 722.65625 1144.53125], Predicted Vowel: a
# Formants: [ 425.78125 2105.46875], Predicted Vowel: e
# Formants: [ 437.5    2101.5625], Predicted Vowel: e
# Formants: [335.9375  699.21875], Predicted Vowel: u
# Formants: [378.90625 671.875  ], Predicted Vowel: u
# Formants: [ 433.59375 2125.     ], Predicted Vowel: e
# Formants: [ 402.34375 1000.     ], Predicted Vowel: u
# Formants: [  3.90625 332.03125], Predicted Vowel: u
# Formants: [ 449.21875 1996.09375], Predicted Vowel: e
# Formants: [363.28125 753.90625], Predicted Vowel: u
# Formants: [ 703.125 1078.125], Predicted Vowel: a
# Formants: [449.21875 625.     ], Predicted Vowel: u
# Formants: [ 375.      1972.65625], Predicted Vowel: e
# Formants: [ 753.90625 1121.09375], Predicted Vowel: a
# Formants: [ 734.375   1191.40625], Predicted Vowel: a
# Formants: [ 781.25   1164.0625], Predicted Vowel: a
# Formants: [363.28125 757.8125 ], Predicted Vowel: u
# Formants: [ 398.4375 2257.8125], Predicted Vowel: e
# Formants: [ 742.1875 1101.5625], Predicted Vowel: a
# Formants: [ 734.375   1167.96875], Predicted Vowel: a
# Formants: [363.28125 773.4375 ], Predicted Vowel: u
# Formants: [300.78125 644.53125], Predicted Vowel: u
# Formants: [ 730.46875 1089.84375], Predicted Vowel: a
# Formants: [ 746.09375 1265.625  ], Predicted Vowel: a
# Formants: [ 742.1875  1136.71875], Predicted Vowel: a
# Formants: [ 761.71875 1089.84375], Predicted Vowel: a
# Formants: [363.28125 832.03125], Predicted Vowel: u
# Formants: [ 417.96875 2136.71875], Predicted Vowel: e
# Formants: [ 757.8125 1195.3125], Predicted Vowel: a
# Formants: [ 773.4375  1144.53125], Predicted Vowel: a
# Formants: [335.9375 687.5   ], Predicted Vowel: u
# Formants: [ 433.59375 2023.4375 ], Predicted Vowel: e
# Formants: [ 417.96875 2015.625  ], Predicted Vowel: e
# Formants: [367.1875  800.78125], Predicted Vowel: u
# Formants: [ 421.875 2078.125], Predicted Vowel: e
# Formants: [ 726.5625  1121.09375], Predicted Vowel: a
# Formants: [351.5625  667.96875], Predicted Vowel: u
# Formants: [363.28125 773.4375 ], Predicted Vowel: u
# Formants: [ 433.59375 2015.625  ], Predicted Vowel: e
# Formants: [ 750.     1117.1875], Predicted Vowel: a
# Formants: [355.46875 703.125  ], Predicted Vowel: u
# Formants: [ 753.90625 1171.875  ], Predicted Vowel: a
# Formants: [382.8125 703.125 ], Predicted Vowel: u
# Formants: [ 699.21875 1128.90625], Predicted Vowel: a
# Formants: [304.6875 757.8125], Predicted Vowel: u
# Formants: [359.375 703.125], Predicted Vowel: u
# Formants: [367.1875  722.65625], Predicted Vowel: u
# Formants: [ 410.15625 2152.34375], Predicted Vowel: e
# Formants: [ 421.875   2027.34375], Predicted Vowel: e
# Formants: [363.28125 695.3125 ], Predicted Vowel: u
# Formants: [ 769.53125 1109.375  ], Predicted Vowel: a
# Formants: [347.65625 687.5    ], Predicted Vowel: u
# Formants: [367.1875  699.21875], Predicted Vowel: u
# Formants: [ 746.09375 1250.     ], Predicted Vowel: a
# Formants: [ 769.53125 1132.8125 ], Predicted Vowel: a
# Formants: [ 773.4375  1160.15625], Predicted Vowel: a
# Formants: [ 449.21875 2093.75   ], Predicted Vowel: e
# Formants: [ 402.34375 2250.     ], Predicted Vowel: e
# Formants: [ 425.78125 2089.84375], Predicted Vowel: e
# Formants: [ 734.375  1195.3125], Predicted Vowel: a
# Formants: [ 750.      1097.65625], Predicted Vowel: a
# Formants: [ 406.25    2246.09375], Predicted Vowel: e
# Formants: [ 441.40625 2105.46875], Predicted Vowel: e
# Formants: [ 429.6875 1992.1875], Predicted Vowel: e
# Formants: [ 480.46875 2023.4375 ], Predicted Vowel: e
# Formants: [304.6875  714.84375], Predicted Vowel: u
# Formants: [363.28125 699.21875], Predicted Vowel: u
# Formants: [ 425.78125 2113.28125], Predicted Vowel: e
# Formants: [ 476.5625 2078.125 ], Predicted Vowel: e
# Formants: [ 441.40625 2148.4375 ], Predicted Vowel: e
# Formants: [359.375   792.96875], Predicted Vowel: u
# Formants: [312.5 750. ], Predicted Vowel: u
# Formants: [ 703.125  1148.4375], Predicted Vowel: a
# Formants: [382.8125  847.65625], Predicted Vowel: u
# Formants: [ 785.15625 1175.78125], Predicted Vowel: a
# Formants: [359.375 703.125], Predicted Vowel: u
# Formants: [ 410.15625 2085.9375 ], Predicted Vowel: e
# Formants: [ 769.53125 1097.65625], Predicted Vowel: a
# Formants: [390.625  867.1875], Predicted Vowel: u
# Formants: [ 429.6875  2027.34375], Predicted Vowel: e
# Formants: [ 515.625 2015.625], Predicted Vowel: e
# Formants: [ 398.4375  2199.21875], Predicted Vowel: e
# Formants: [ 773.4375  1121.09375], Predicted Vowel: a
# Formants: [ 773.4375 1117.1875], Predicted Vowel: a
# Formants: [ 429.6875 1984.375 ], Predicted Vowel: e
# Formants: [367.1875  722.65625], Predicted Vowel: u
# Formants: [ 695.3125  1113.28125], Predicted Vowel: a
# Formants: [367.1875 750.    ], Predicted Vowel: u
# Formants: [ 769.53125 1109.375  ], Predicted Vowel: a
# Formants: [417.96875 867.1875 ], Predicted Vowel: u
# Formants: [339.84375 667.96875], Predicted Vowel: u
# Formants: [ 457.03125 2058.59375], Predicted Vowel: e
# Formants: [ 722.65625 1121.09375], Predicted Vowel: a
# Formants: [ 773.4375 1171.875 ], Predicted Vowel: a
# Formants: [363.28125 773.4375 ], Predicted Vowel: u
# Formants: [ 777.34375 1414.0625 ], Predicted Vowel: a
# Formants: [ 761.71875 1121.09375], Predicted Vowel: a
# Formants: [273.4375 546.875 ], Predicted Vowel: u
# Formants: [332.03125 691.40625], Predicted Vowel: u
# Formants: [ 730.46875 1082.03125], Predicted Vowel: a
# Formants: [ 421.875   2019.53125], Predicted Vowel: e
# Formants: [328.125   660.15625], Predicted Vowel: u
# Formants: [ 472.65625 2019.53125], Predicted Vowel: e
# Formants: [ 472.65625 2023.4375 ], Predicted Vowel: e
# Formants: [371.09375 703.125  ], Predicted Vowel: u
# Formants: [ 718.75    1144.53125], Predicted Vowel: a
# Formants: [ 699.21875 1042.96875], Predicted Vowel: a
# Formants: [300.78125 671.875  ], Predicted Vowel: u
# Formants: [339.84375 691.40625], Predicted Vowel: u
# Formants: [ 773.4375 1109.375 ], Predicted Vowel: a
# Formants: [ 417.96875 2054.6875 ], Predicted Vowel: e
# Formants: [156.25   476.5625], Predicted Vowel: u
# Formants: [ 738.28125 1160.15625], Predicted Vowel: a
# Formants: [ 742.1875  1097.65625], Predicted Vowel: a
# Formants: [ 398.4375 2265.625 ], Predicted Vowel: e
# Formants: [ 750.      1128.90625], Predicted Vowel: a
# Formants: [ 367.1875 2281.25  ], Predicted Vowel: e
# Formants: [371.09375 691.40625], Predicted Vowel: u
# Formants: [ 378.90625 1988.28125], Predicted Vowel: e
# Formants: [ 398.4375 2242.1875], Predicted Vowel: e
# Formants: [ 785.15625 1132.8125 ], Predicted Vowel: a
# Formants: [ 730.46875 1175.78125], Predicted Vowel: a
# Formants: [414.0625 742.1875], Predicted Vowel: u
# Formants: [371.09375 750.     ], Predicted Vowel: u
# Formants: [ 296.875   2269.53125], Predicted Vowel: e
# Formants: [ 425.78125 2023.4375 ], Predicted Vowel: e
# Formants: [ 398.4375  2238.28125], Predicted Vowel: e
# Formants: [406.25   820.3125], Predicted Vowel: u
# Formants: [ 460.9375 2085.9375], Predicted Vowel: e
# Formants: [359.375   738.28125], Predicted Vowel: u
# Formants: [ 308.59375 1960.9375 ], Predicted Vowel: e
# Formants: [ 429.6875 2023.4375], Predicted Vowel: e
# Formants: [ 769.53125 1101.5625 ], Predicted Vowel: a
# Formants: [347.65625 742.1875 ], Predicted Vowel: u
# Formants: [320.3125 718.75  ], Predicted Vowel: u
# Formants: [414.0625  816.40625], Predicted Vowel: u
# Formants: [394.53125 753.90625], Predicted Vowel: u
# Formants: [371.09375 753.90625], Predicted Vowel: u
# Formants: [367.1875 710.9375], Predicted Vowel: u
# Formants: [414.0625 828.125 ], Predicted Vowel: u
# Formants: [ 714.84375 1152.34375], Predicted Vowel: a
# Formants: [375.     679.6875], Predicted Vowel: u
# Formants: [ 398.4375  2246.09375], Predicted Vowel: e
# Formants: [410.15625 800.78125], Predicted Vowel: u
# Formants: [406.25    855.46875], Predicted Vowel: u
# Formants: [343.75   664.0625], Predicted Vowel: u
# Formants: [ 671.875  1085.9375], Predicted Vowel: a
# Formants: [ 453.125   2066.40625], Predicted Vowel: e
# Formants: [ 746.09375 1089.84375], Predicted Vowel: a
# Formants: [ 691.40625 1121.09375], Predicted Vowel: a
# Formants: [ 710.9375  1113.28125], Predicted Vowel: a
# Formants: [ 699.21875 1132.8125 ], Predicted Vowel: a
# Formants: [ 421.875 2031.25 ], Predicted Vowel: e
# Formants: [ 777.34375 1113.28125], Predicted Vowel: a
# Formants: [ 699.21875 1117.1875 ], Predicted Vowel: a
# Formants: [ 437.5    2070.3125], Predicted Vowel: e
# Formants: [ 699.21875 1027.34375], Predicted Vowel: a
# Formants: [367.1875 750.    ], Predicted Vowel: u
# Formants: [246.09375 671.875  ], Predicted Vowel: u
# Formants: [ 761.71875 1125.     ], Predicted Vowel: a
# Formants: [ 753.90625 1085.9375 ], Predicted Vowel: a
# Formants: [ 699.21875 1152.34375], Predicted Vowel: a
# Formants: [335.9375  730.46875], Predicted Vowel: u
# Formants: [ 359.375   2246.09375], Predicted Vowel: e
# Formants: [ 371.09375 2066.40625], Predicted Vowel: e
# Formants: [234.375   761.71875], Predicted Vowel: u
# Formants: [ 316.40625 2058.59375], Predicted Vowel: e
# Formants: [ 468.75    2066.40625], Predicted Vowel: e
# Formants: [347.65625 718.75   ], Predicted Vowel: u
# Formants: [378.90625 785.15625], Predicted Vowel: u
# Formants: [375.     664.0625], Predicted Vowel: u
# Formants: [414.0625 734.375 ], Predicted Vowel: u
# Formants: [ 316.40625 1906.25   ], Predicted Vowel: e
# Formants: [ 472.65625 2066.40625], Predicted Vowel: e
# Formants: [343.75   710.9375], Predicted Vowel: u
# Formants: [ 476.5625  2089.84375], Predicted Vowel: e
# Formants: [ 457.03125 2105.46875], Predicted Vowel: e
# Formants: [ 703.125 1140.625], Predicted Vowel: a
# Formants: [406.25    683.59375], Predicted Vowel: u
# Formants: [ 417.96875 2023.4375 ], Predicted Vowel: e
# Formants: [289.0625  761.71875], Predicted Vowel: u
# Formants: [363.28125 730.46875], Predicted Vowel: u
# Formants: [417.96875 816.40625], Predicted Vowel: u
# Formants: [ 726.5625 1125.    ], Predicted Vowel: a
# Formants: [ 339.84375 2058.59375], Predicted Vowel: e
# Formants: [ 738.28125 1269.53125], Predicted Vowel: a
# Formants: [ 707.03125 1082.03125], Predicted Vowel: a
# Formants: [ 761.71875 1128.90625], Predicted Vowel: a
# Formants: [ 777.34375 1101.5625 ], Predicted Vowel: a
# Formants: [ 746.09375 1050.78125], Predicted Vowel: a
# Formants: [371.09375 773.4375 ], Predicted Vowel: u
# Formants: [359.375   753.90625], Predicted Vowel: u
# Formants: [ 429.6875  2011.71875], Predicted Vowel: e
# Formants: [394.53125 773.4375 ], Predicted Vowel: u
# Formants: [ 750.   1093.75], Predicted Vowel: a
# Formants: [414.0625 765.625 ], Predicted Vowel: u
# Formants: [ 464.84375 2113.28125], Predicted Vowel: e
# Formants: [394.53125 664.0625 ], Predicted Vowel: u
# Formants: [343.75    714.84375], Predicted Vowel: u
# Formants: [ 730.46875 1246.09375], Predicted Vowel: a
# Formants: [ 750.      1097.65625], Predicted Vowel: a
# Formants: [ 398.4375  2253.90625], Predicted Vowel: e
# Formants: [332.03125 691.40625], Predicted Vowel: u
# Formants: [363.28125 707.03125], Predicted Vowel: u
# Formants: [ 359.375   2277.34375], Predicted Vowel: e
# Formants: [ 433.59375 2109.375  ], Predicted Vowel: e
# Formants: [ 695.3125  1152.34375], Predicted Vowel: a
# Formants: [ 687.5    1085.9375], Predicted Vowel: a
# Formants: [351.5625  636.71875], Predicted Vowel: u
# Formants: [359.375  757.8125], Predicted Vowel: u
# Formants: [ 707.03125 1132.8125 ], Predicted Vowel: a
# Formants: [ 480.46875 2093.75   ], Predicted Vowel: e
# Formants: [378.90625 808.59375], Predicted Vowel: u
# Formants: [ 386.71875 2222.65625], Predicted Vowel: e
# Formants: [ 773.4375 1109.375 ], Predicted Vowel: a
# Formants: [ 722.65625 1191.40625], Predicted Vowel: a
# Formants: [ 750.     1054.6875], Predicted Vowel: a
# Formants: [347.65625 703.125  ], Predicted Vowel: u
# Formants: [ 785.15625 1144.53125], Predicted Vowel: a
# Formants: [ 472.65625 2074.21875], Predicted Vowel: e
# Formants: [ 746.09375 1070.3125 ], Predicted Vowel: a
# Formants: [351.5625  714.84375], Predicted Vowel: u
# Formants: [ 453.125 2015.625], Predicted Vowel: e
# Formants: [ 914.0625  1175.78125], Predicted Vowel: a
# Formants: [328.125 687.5  ], Predicted Vowel: u
# Formants: [ 773.4375 1101.5625], Predicted Vowel: a
# Formants: [500.      839.84375], Predicted Vowel: u
# Formants: [378.90625 855.46875], Predicted Vowel: u
# Formants: [  3.90625 375.     ], Predicted Vowel: u
# Formants: [378.90625 726.5625 ], Predicted Vowel: u
# Formants: [ 468.75    2082.03125], Predicted Vowel: e
# Formants: [ 468.75 2093.75], Predicted Vowel: e
# Formants: [ 746.09375 1105.46875], Predicted Vowel: a
# Formants: [ 386.71875 2289.0625 ], Predicted Vowel: e
# Formants: [ 492.1875  2097.65625], Predicted Vowel: e
# Formants: [367.1875 742.1875], Predicted Vowel: u
# Formants: [ 421.875 2109.375], Predicted Vowel: e
# Formants: [ 785.15625 1148.4375 ], Predicted Vowel: a
# Formants: [335.9375  605.46875], Predicted Vowel: u
# Formants: [ 750.     1132.8125], Predicted Vowel: a
# Formants: [ 398.4375 2125.    ], Predicted Vowel: e
# Formants: [ 753.90625 1289.0625 ], Predicted Vowel: a
# Formants: [ 433.59375 2023.4375 ], Predicted Vowel: e
# Formants: [390.625   761.71875], Predicted Vowel: u
# Formants: [ 410.15625 1000.     ], Predicted Vowel: u
# Formants: [ 484.375   2113.28125], Predicted Vowel: e
# Formants: [375.     757.8125], Predicted Vowel: u
# Formants: [ 750.      1261.71875], Predicted Vowel: a
# Formants: [ 699.21875 1152.34375], Predicted Vowel: a
# Formants: [ 472.65625 2089.84375], Predicted Vowel: e
# Formants: [ 734.375   1121.09375], Predicted Vowel: a
# Formants: [ 691.40625 1031.25   ], Predicted Vowel: a
# Formants: [ 328.125  2289.0625], Predicted Vowel: e
# Formants: [363.28125 851.5625 ], Predicted Vowel: u
# Formants: [332.03125 714.84375], Predicted Vowel: u
# Formants: [ 726.5625 1218.75  ], Predicted Vowel: a
# Formants: [ 750.   1093.75], Predicted Vowel: a
# Formants: [ 738.28125 1082.03125], Predicted Vowel: a
# Formants: [ 730.46875 1234.375  ], Predicted Vowel: a
# Formants: [433.59375 605.46875], Predicted Vowel: u
# Formants: [ 773.4375 1117.1875], Predicted Vowel: a
# Formants: [ 726.5625 1242.1875], Predicted Vowel: a
# Formants: [ 398.4375 2234.375 ], Predicted Vowel: e
# Formants: [359.375 718.75 ], Predicted Vowel: u
# Formants: [363.28125 707.03125], Predicted Vowel: u
# Formants: [ 781.25    1144.53125], Predicted Vowel: a
# Formants: [ 734.375   1246.09375], Predicted Vowel: a
# Formants: [ 742.1875 1101.5625], Predicted Vowel: a
# Formants: [ 695.3125 1062.5   ], Predicted Vowel: a
# Formants: [ 691.40625 1140.625  ], Predicted Vowel: a
# Formants: [ 707.03125 1140.625  ], Predicted Vowel: a
# Formants: [355.46875 750.     ], Predicted Vowel: u
# Formants: [ 796.875   1253.90625], Predicted Vowel: a
# Formants: [ 703.125   1113.28125], Predicted Vowel: a
# Formants: [ 781.25 1156.25], Predicted Vowel: a
# Formants: [ 433.59375 2027.34375], Predicted Vowel: e
# Formants: [ 750.   1093.75], Predicted Vowel: a
# Formants: [ 714.84375 1089.84375], Predicted Vowel: a
# Formants: [ 421.875   2058.59375], Predicted Vowel: e
# Formants: [ 738.28125 1082.03125], Predicted Vowel: a
# Formants: [ 707.03125 1144.53125], Predicted Vowel: a
# Formants: [  3.90625 367.1875 ], Predicted Vowel: u
# Formants: [355.46875 722.65625], Predicted Vowel: u
# Formants: [ 335.9375 2046.875 ], Predicted Vowel: e
# Formants: [ 398.4375 2085.9375], Predicted Vowel: e
# Formants: [355.46875 718.75   ], Predicted Vowel: u
# Formants: [371.09375 859.375  ], Predicted Vowel: u
# Formants: [ 738.28125 1156.25   ], Predicted Vowel: a
# Formants: [ 335.9375 1000.    ], Predicted Vowel: u
# Formants: [320.3125 695.3125], Predicted Vowel: u
# Formants: [ 433.59375 2042.96875], Predicted Vowel: e
# Formants: [ 781.25    1121.09375], Predicted Vowel: a
# Formants: [445.3125 851.5625], Predicted Vowel: u
# Formants: [371.09375 695.3125 ], Predicted Vowel: u
# Formants: [ 417.96875 2148.4375 ], Predicted Vowel: e
# Formants: [ 449.21875 2074.21875], Predicted Vowel: e
# Formants: [363.28125 750.     ], Predicted Vowel: u
# Formants: [347.65625 714.84375], Predicted Vowel: u
# Formants: [445.3125 851.5625], Predicted Vowel: u
# Formants: [ 429.6875  2144.53125], Predicted Vowel: e
# Formants: [ 792.96875 1109.375  ], Predicted Vowel: a
# Formants: [394.53125 695.3125 ], Predicted Vowel: u
# Formants: [355.46875 746.09375], Predicted Vowel: u
# Formants: [363.28125 753.90625], Predicted Vowel: u
# Formants: [363.28125 722.65625], Predicted Vowel: u
# Formants: [ 746.09375 1093.75   ], Predicted Vowel: a
# Formants: [ 718.75    1214.84375], Predicted Vowel: a
# Formants: [347.65625 714.84375], Predicted Vowel: u
# Formants: [ 472.65625 2039.0625 ], Predicted Vowel: e
# Formants: [347.65625 703.125  ], Predicted Vowel: u
# Formants: [ 742.1875  1089.84375], Predicted Vowel: a
# Formants: [ 394.53125 1941.40625], Predicted Vowel: e
# Formants: [324.21875 652.34375], Predicted Vowel: u
# Formants: [320.3125 687.5   ], Predicted Vowel: u
# Formants: [ 757.8125 1109.375 ], Predicted Vowel: a
# Formants: [367.1875  675.78125], Predicted Vowel: u
# Formants: [363.28125 722.65625], Predicted Vowel: u
# Formants: [414.0625 867.1875], Predicted Vowel: u
# Formants: [ 468.75   2117.1875], Predicted Vowel: e
# Formants: [ 417.96875 2089.84375], Predicted Vowel: e
# Formants: [ 488.28125 2093.75   ], Predicted Vowel: e
# Formants: [347.65625 804.6875 ], Predicted Vowel: u
# Formants: [ 691.40625 1109.375  ], Predicted Vowel: a
# Formants: [ 277.34375 2285.15625], Predicted Vowel: e
# Formants: [ 714.84375 1000.     ], Predicted Vowel: a
# Formants: [375.    796.875], Predicted Vowel: u
# Formants: [ 417.96875 2046.875  ], Predicted Vowel: e
# Formants: [308.59375 738.28125], Predicted Vowel: u
# Formants: [ 429.6875  2027.34375], Predicted Vowel: e
# Formants: [ 457.03125 2101.5625 ], Predicted Vowel: e
# Formants: [ 757.8125 1117.1875], Predicted Vowel: a
# Formants: [367.1875  746.09375], Predicted Vowel: u
# Formants: [ 773.4375 1109.375 ], Predicted Vowel: a
# Formants: [ 742.1875  1105.46875], Predicted Vowel: a
# Formants: [355.46875 742.1875 ], Predicted Vowel: u
# Formants: [363.28125 722.65625], Predicted Vowel: u
# Formants: [ 402.34375 2242.1875 ], Predicted Vowel: e
# Formants: [ 441.40625 2128.90625], Predicted Vowel: e
# Formants: [ 500.      2066.40625], Predicted Vowel: e
# Formants: [ 714.84375 1144.53125], Predicted Vowel: a
# Formants: [437.5   765.625], Predicted Vowel: u
# Formants: [ 386.71875 2257.8125 ], Predicted Vowel: e
# Formants: [378.90625 671.875  ], Predicted Vowel: u
# Formants: [343.75    621.09375], Predicted Vowel: u
# Formants: [441.40625 875.     ], Predicted Vowel: u
# Formants: [312.5   765.625], Predicted Vowel: u
# Formants: [ 765.625  1117.1875], Predicted Vowel: a
# Formants: [343.75 781.25], Predicted Vowel: u
# Formants: [363.28125 742.1875 ], Predicted Vowel: u
# Formants: [ 777.34375 1105.46875], Predicted Vowel: a
# Formants: [425.78125 859.375  ], Predicted Vowel: u
# Formants: [ 699.21875 1109.375  ], Predicted Vowel: a
# Formants: [464.84375 886.71875], Predicted Vowel: u
# Formants: [ 429.6875  2050.78125], Predicted Vowel: e
# Formants: [ 777.34375 1117.1875 ], Predicted Vowel: a
# Formants: [324.21875 703.125  ], Predicted Vowel: u
# Formants: [ 437.5    2039.0625], Predicted Vowel: e
# Formants: [394.53125 746.09375], Predicted Vowel: u
# Formants: [ 390.625   2246.09375], Predicted Vowel: e
# Formants: [ 757.8125 1117.1875], Predicted Vowel: a
# Formants: [312.5   734.375], Predicted Vowel: u
# Formants: [ 476.5625  2089.84375], Predicted Vowel: e
# Formants: [347.65625 707.03125], Predicted Vowel: u
# Formants: [ 500.      2066.40625], Predicted Vowel: e
# Formants: [371.09375 769.53125], Predicted Vowel: u
# Formants: [ 335.9375  2285.15625], Predicted Vowel: e
# Formants: [ 421.875   1996.09375], Predicted Vowel: e
# Formants: [ 453.125   2074.21875], Predicted Vowel: e
# Formants: [ 433.59375 2066.40625], Predicted Vowel: e
# Formants: [ 468.75  2015.625], Predicted Vowel: e
# ...
# Formants: [363.28125 757.8125 ], Predicted Vowel: u
# Formants: [335.9375 687.5   ], Predicted Vowel: u
# Formants: [ 789.0625  1113.28125], Predicted Vowel: a
# Formants: [ 707.03125 1050.78125], Predicted Vowel: a
# Formants: [ 746.09375 1101.5625 ], Predicted Vowel: a
# Formants: [ 722.65625 1136.71875], Predicted Vowel: a
# Formants: [ 433.59375 2148.4375 ], Predicted Vowel: e
# Formants: [406.25 812.5 ], Predicted Vowel: u
# Formants: [ 687.5   1109.375], Predicted Vowel: a
# Formants: [ 746.09375 1000.     ], Predicted Vowel: a
# Formants: [ 773.4375 1109.375 ], Predicted Vowel: a
# Formants: [ 289.0625 2000.    ], Predicted Vowel: e
# Formants: [347.65625 730.46875], Predicted Vowel: u
# Formants: [ 464.84375 2019.53125], Predicted Vowel: e
# Formants: [ 421.875   2097.65625], Predicted Vowel: e
# Formants: [ 382.8125 2132.8125], Predicted Vowel: e
# Formants: [457.03125 890.625  ], Predicted Vowel: u
# Formants: [363.28125 742.1875 ], Predicted Vowel: u
# Formants: [ 425.78125 1976.5625 ], Predicted Vowel: e
# Formants: [ 785.15625 1121.09375], Predicted Vowel: a
# Formants: [ 398.4375 2250.    ], Predicted Vowel: e
# Formants: [ 445.3125  2074.21875], Predicted Vowel: e
# Formants: [ 722.65625 1109.375  ], Predicted Vowel: a
# Formants: [ 726.5625  1128.90625], Predicted Vowel: a
# Formants: [363.28125 796.875  ], Predicted Vowel: u
# Formants: [ 433.59375 2121.09375], Predicted Vowel: e
# Formants: [ 429.6875 2148.4375], Predicted Vowel: e
# Formants: [402.34375 812.5    ], Predicted Vowel: u
# Formants: [367.1875 757.8125], Predicted Vowel: u
# Formants: [351.5625  714.84375], Predicted Vowel: u
# Formants: [ 371.09375 2097.65625], Predicted Vowel: e
# Formants: [359.375  820.3125], Predicted Vowel: u
# Formants: [ 472.65625 2015.625  ], Predicted Vowel: e
# Formants: [ 691.40625 1039.0625 ], Predicted Vowel: a
# Formants: [355.46875 710.9375 ], Predicted Vowel: u
# Formants: [ 363.28125 2222.65625], Predicted Vowel: e
# Formants: [ 429.6875 1960.9375], Predicted Vowel: e
# Formants: [320.3125  699.21875], Predicted Vowel: u
# Formants: [355.46875 730.46875], Predicted Vowel: u
# Formants: [312.5 750. ], Predicted Vowel: u
# Formants: [ 472.65625 2074.21875], Predicted Vowel: e
# Formants: [304.6875  722.65625], Predicted Vowel: u
# Formants: [367.1875 687.5   ], Predicted Vowel: u
# Formants: [371.09375 742.1875 ], Predicted Vowel: u
# Formants: [ 351.5625 2046.875 ], Predicted Vowel: e
# Formants: [355.46875 722.65625], Predicted Vowel: u
# Formants: [ 710.9375 1140.625 ], Predicted Vowel: a
# Formants: [ 730.46875 1035.15625], Predicted Vowel: a
# Formants: [ 789.0625 1109.375 ], Predicted Vowel: a
# Formants: [ 394.53125 2125.     ], Predicted Vowel: e
# Formants: [ 777.34375 1101.5625 ], Predicted Vowel: a
# Formants: [417.96875 839.84375], Predicted Vowel: u
# Formants: [ 414.0625 2023.4375], Predicted Vowel: e
# Formants: [ 750.      1292.96875], Predicted Vowel: a
# Formants: [ 726.5625  1175.78125], Predicted Vowel: a
# Formants: [ 773.4375 1117.1875], Predicted Vowel: a
# Formants: [347.65625 714.84375], Predicted Vowel: u
# Formants: [359.375   761.71875], Predicted Vowel: u
# Formants: [ 742.1875 1093.75  ], Predicted Vowel: a
# Formants: [ 449.21875 2097.65625], Predicted Vowel: e
# Formants: [ 769.53125 1144.53125], Predicted Vowel: a
# Formants: [ 726.5625 1117.1875], Predicted Vowel: a
# Formants: [324.21875 730.46875], Predicted Vowel: u
# Formants: [359.375   730.46875], Predicted Vowel: u
# Formants: [ 386.71875 2222.65625], Predicted Vowel: e
# Formants: [ 476.5625  2058.59375], Predicted Vowel: e
# Formants: [ 714.84375 1132.8125 ], Predicted Vowel: a
# Formants: [332.03125 718.75   ], Predicted Vowel: u
# Formants: [382.8125  792.96875], Predicted Vowel: u
# Formants: [ 429.6875  2082.03125], Predicted Vowel: e
# Formants: [347.65625 714.84375], Predicted Vowel: u
# Formants: [347.65625 750.     ], Predicted Vowel: u
# Formants: [ 441.40625 2023.4375 ], Predicted Vowel: e
# Formants: [296.875   683.59375], Predicted Vowel: u
# Formants: [ 691.40625 1140.625  ], Predicted Vowel: a
# Formants: [ 730.46875 1269.53125], Predicted Vowel: a
# Formants: [ 433.59375 2050.78125], Predicted Vowel: e
# Formants: [ 734.375   1152.34375], Predicted Vowel: a
# Formants: [  3.90625 343.75   ], Predicted Vowel: u
# Formants: [363.28125 761.71875], Predicted Vowel: u
# Formants: [ 687.5     1105.46875], Predicted Vowel: a
# Formants: [ 785.15625 1160.15625], Predicted Vowel: a
# Formants: [324.21875 683.59375], Predicted Vowel: u
# Formants: [347.65625 710.9375 ], Predicted Vowel: u
# Formants: [ 398.4375 2234.375 ], Predicted Vowel: e
# Formants: [ 421.875 2109.375], Predicted Vowel: e
# Formants: [ 785.15625 1152.34375], Predicted Vowel: a
# Formants: [ 769.53125 1117.1875 ], Predicted Vowel: a
# Formants: [359.375   667.96875], Predicted Vowel: u
# Formants: [164.0625 460.9375], Predicted Vowel: u
# Formants: [292.96875 750.     ], Predicted Vowel: u
# Formants: [ 792.96875 1109.375  ], Predicted Vowel: a
# Formants: [ 789.0625  1144.53125], Predicted Vowel: a
# Formants: [ 464.84375 2085.9375 ], Predicted Vowel: e
# Formants: [ 421.875 2031.25 ], Predicted Vowel: e
# Formants: [ 730.46875 1066.40625], Predicted Vowel: a
# Formants: [ 718.75   1164.0625], Predicted Vowel: a
# Formants: [406.25    777.34375], Predicted Vowel: u
# Formants: [332.03125 679.6875 ], Predicted Vowel: u
# Formants: [ 296.875   2058.59375], Predicted Vowel: e
# Formants: [ 777.34375 1148.4375 ], Predicted Vowel: a
# Formants: [ 789.0625 1132.8125], Predicted Vowel: a
# Formants: [ 390.625  2242.1875], Predicted Vowel: e
# Formants: [363.28125 769.53125], Predicted Vowel: u
# Formants: [ 785.15625 1156.25   ], Predicted Vowel: a
# Formants: [ 382.8125 2203.125 ], Predicted Vowel: e
# Formants: [ 441.40625 2082.03125], Predicted Vowel: e
# Formants: [ 421.875 2062.5  ], Predicted Vowel: e
# Formants: [ 753.90625 1113.28125], Predicted Vowel: a
# Formants: [ 738.28125 1160.15625], Predicted Vowel: a
# Formants: [ 703.125  1132.8125], Predicted Vowel: a
# Formants: [359.375   777.34375], Predicted Vowel: u
# Formants: [ 777.34375 1167.96875], Predicted Vowel: a
# Formants: [ 742.1875 1203.125 ], Predicted Vowel: a
# Formants: [ 695.3125 1093.75  ], Predicted Vowel: a
# Formants: [429.6875  832.03125], Predicted Vowel: u
# Formants: [339.84375 703.125  ], Predicted Vowel: u
# Formants: [ 402.34375 2093.75   ], Predicted Vowel: e
# Formants: [ 718.75    1113.28125], Predicted Vowel: a
# Formants: [371.09375 882.8125 ], Predicted Vowel: u
# Formants: [402.34375 738.28125], Predicted Vowel: u
# Formants: [ 718.75   1085.9375], Predicted Vowel: a
# Formants: [375.      699.21875], Predicted Vowel: u
# Formants: [363.28125 746.09375], Predicted Vowel: u
# Formants: [ 382.8125 2125.    ], Predicted Vowel: e
# Formants: [ 734.375   1230.46875], Predicted Vowel: a
# Formants: [ 730.46875 1109.375  ], Predicted Vowel: a
# Formants: [ 472.65625 2089.84375], Predicted Vowel: e
# Formants: [324.21875 714.84375], Predicted Vowel: u
# Formants: [367.1875 742.1875], Predicted Vowel: u
# Formants: [ 429.6875 2031.25  ], Predicted Vowel: e
# Formants: [ 742.1875 1078.125 ], Predicted Vowel: a
# Formants: [ 746.09375 1140.625  ], Predicted Vowel: a
# Formants: [ 429.6875  2121.09375], Predicted Vowel: e
# Formants: [ 734.375 1062.5  ], Predicted Vowel: a
# Formants: [351.5625  722.65625], Predicted Vowel: u
# Formants: [ 718.75    1222.65625], Predicted Vowel: a
# Formants: [ 464.84375 2039.0625 ], Predicted Vowel: e
# Formants: [457.03125 894.53125], Predicted Vowel: u
# Formants: [ 464.84375 2101.5625 ], Predicted Vowel: e
# Formants: [ 437.5    2101.5625], Predicted Vowel: e
# Formants: [ 746.09375 1070.3125 ], Predicted Vowel: a
# Formants: [ 734.375   1183.59375], Predicted Vowel: a
# Formants: [ 382.8125 2031.25  ], Predicted Vowel: e
# Formants: [339.84375 675.78125], Predicted Vowel: u
# Formants: [ 496.09375 2097.65625], Predicted Vowel: e
# Formants: [339.84375 695.3125 ], Predicted Vowel: u
# Formants: [ 324.21875 2093.75   ], Predicted Vowel: e
# Formants: [ 472.65625 2078.125  ], Predicted Vowel: e
# Formants: [371.09375 730.46875], Predicted Vowel: u
# Formants: [417.96875 820.3125 ], Predicted Vowel: u
# Formants: [ 785.15625 1152.34375], Predicted Vowel: a
# Formants: [ 710.9375  1089.84375], Predicted Vowel: a
# Formants: [ 714.84375 1132.8125 ], Predicted Vowel: a
# Formants: [ 308.59375 2101.5625 ], Predicted Vowel: e
# Formants: [421.875   832.03125], Predicted Vowel: u
# Formants: [ 792.96875 1117.1875 ], Predicted Vowel: a
# Formants: [378.90625 898.4375 ], Predicted Vowel: u
# Formants: [ 746.09375 1066.40625], Predicted Vowel: a
# Formants: [ 597.65625 1917.96875], Predicted Vowel: e
# Formants: [ 707.03125 1152.34375], Predicted Vowel: a
# Formants: [359.375  773.4375], Predicted Vowel: u
# Formants: [394.53125 804.6875 ], Predicted Vowel: u
# Formants: [296.875 718.75 ], Predicted Vowel: u
# Formants: [359.375  710.9375], Predicted Vowel: u
# Formants: [ 699.21875 1160.15625], Predicted Vowel: a
# Formants: [ 707.03125 1078.125  ], Predicted Vowel: a
# Formants: [ 355.46875 2058.59375], Predicted Vowel: e
# Formants: [ 691.40625 1035.15625], Predicted Vowel: a
# Formants: [367.1875 703.125 ], Predicted Vowel: u
# Formants: [ 773.4375 1117.1875], Predicted Vowel: a
# Formants: [ 390.625  1554.6875], Predicted Vowel: e
# Formants: [363.28125 703.125  ], Predicted Vowel: u
# Formants: [ 707.03125 1039.0625 ], Predicted Vowel: a
# Formants: [312.5     753.90625], Predicted Vowel: u
# Formants: [ 753.90625 1042.96875], Predicted Vowel: a
# Formants: [316.40625 718.75   ], Predicted Vowel: u
# Formants: [ 777.34375 1105.46875], Predicted Vowel: a
# Formants: [ 468.75   1992.1875], Predicted Vowel: e
# Formants: [ 761.71875 1089.84375], Predicted Vowel: a
# Formants: [ 777.34375 1140.625  ], Predicted Vowel: a
# Formants: [ 730.46875 1191.40625], Predicted Vowel: a
# Formants: [ 453.125   2105.46875], Predicted Vowel: e
# Formants: [437.5     816.40625], Predicted Vowel: u
# Formants: [ 398.4375  2214.84375], Predicted Vowel: e
# Formants: [ 734.375 1171.875], Predicted Vowel: a
# Formants: [ 750.      1121.09375], Predicted Vowel: a
# Formants: [425.78125 808.59375], Predicted Vowel: u
# Formants: [ 398.4375  2238.28125], Predicted Vowel: e
# Formants: [335.9375  652.34375], Predicted Vowel: u
# Formants: [ 402.34375 2191.40625], Predicted Vowel: e
# Formants: [ 734.375   1222.65625], Predicted Vowel: a
# Formants: [ 480.46875 2015.625  ], Predicted Vowel: e
# Formants: [ 421.875   2042.96875], Predicted Vowel: e
# Formants: [ 710.9375  1089.84375], Predicted Vowel: a
# Formants: [ 691.40625 1148.4375 ], Predicted Vowel: a
# Formants: [ 722.65625 1125.     ], Predicted Vowel: a
# Formants: [347.65625 742.1875 ], Predicted Vowel: u
# Formants: [ 695.3125  1128.90625], Predicted Vowel: a
# Formants: [ 480.46875 2089.84375], Predicted Vowel: e
# Formants: [ 472.65625 2089.84375], Predicted Vowel: e
# Formants: [ 429.6875  2019.53125], Predicted Vowel: e
# Formants: [ 738.28125 1058.59375], Predicted Vowel: a
# Formants: [ 500.      2089.84375], Predicted Vowel: e
# Formants: [ 437.5     2042.96875], Predicted Vowel: e
# Formants: [382.8125 710.9375], Predicted Vowel: u
# Formants: [335.9375 750.    ], Predicted Vowel: u
# Formants: [359.375 781.25 ], Predicted Vowel: u
# Formants: [ 695.3125 1101.5625], Predicted Vowel: a
# Formants: [ 769.53125 1066.40625], Predicted Vowel: a
# Formants: [ 500.      2105.46875], Predicted Vowel: e
# Formants: [ 375.    2265.625], Predicted Vowel: e
# Formants: [417.96875 753.90625], Predicted Vowel: u
# Formants: [ 429.6875  2011.71875], Predicted Vowel: e
# Formants: [ 773.4375  1136.71875], Predicted Vowel: a
# Formants: [ 722.65625 1113.28125], Predicted Vowel: a
# Formants: [ 765.625  1117.1875], Predicted Vowel: a
# Formants: [ 433.59375 2089.84375], Predicted Vowel: e
# Formants: [363.28125 722.65625], Predicted Vowel: u
# Formants: [ 726.5625  1160.15625], Predicted Vowel: a
# Formants: [343.75   742.1875], Predicted Vowel: u
# Formants: [347.65625 714.84375], Predicted Vowel: u
# Formants: [ 519.53125 2074.21875], Predicted Vowel: e
# Formants: [351.5625  707.03125], Predicted Vowel: u
# Formants: [363.28125 699.21875], Predicted Vowel: u
# Formants: [ 378.90625 2097.65625], Predicted Vowel: e
# Formants: [ 339.84375 2257.8125 ], Predicted Vowel: e
# Formants: [339.84375 730.46875], Predicted Vowel: u
# Formants: [ 742.1875  1058.59375], Predicted Vowel: a
# Formants: [ 390.625   2269.53125], Predicted Vowel: e
# Formants: [316.40625 597.65625], Predicted Vowel: u
# Formants: [ 484.375  2070.3125], Predicted Vowel: e
# Formants: [421.875   808.59375], Predicted Vowel: u
# Formants: [ 433.59375 2113.28125], Predicted Vowel: e
# Formants: [ 753.90625 1140.625  ], Predicted Vowel: a
# Formants: [ 753.90625 1109.375  ], Predicted Vowel: a
# Formants: [ 449.21875 2062.5    ], Predicted Vowel: e
# Formants: [359.375 734.375], Predicted Vowel: u
# Formants: [375.      816.40625], Predicted Vowel: u
# Formants: [ 425.78125 2187.5    ], Predicted Vowel: e
# Formants: [ 433.59375 2031.25   ], Predicted Vowel: e
# Formants: [ 453.125  2195.3125], Predicted Vowel: e
# Formants: [296.875 890.625], Predicted Vowel: u
# Formants: [ 468.75    2042.96875], Predicted Vowel: e
# Formants: [371.09375 796.875  ], Predicted Vowel: u
# Formants: [ 722.65625 1164.0625 ], Predicted Vowel: a
# Formants: [ 707.03125 1082.03125], Predicted Vowel: a
# Formants: [449.21875 871.09375], Predicted Vowel: u
# Formants: [ 777.34375 1050.78125], Predicted Vowel: a
# Formants: [ 441.40625 2125.     ], Predicted Vowel: e
# Formants: [339.84375 671.875  ], Predicted Vowel: u
# Formants: [367.1875  722.65625], Predicted Vowel: u
# Formants: [371.09375 750.     ], Predicted Vowel: u
# Formants: [ 441.40625 2085.9375 ], Predicted Vowel: e
# Formants: [ 441.40625 2046.875  ], Predicted Vowel: e
# Formants: [ 351.5625  2292.96875], Predicted Vowel: e
# Formants: [250.      644.53125], Predicted Vowel: u
# Formants: [ 390.625 1000.   ], Predicted Vowel: u
# Formants: [410.15625 867.1875 ], Predicted Vowel: u
# Formants: [ 417.96875 2023.4375 ], Predicted Vowel: e
# Formants: [ 445.3125 2148.4375], Predicted Vowel: e
# Formants: [ 476.5625  2089.84375], Predicted Vowel: e
# Formants: [398.4375 890.625 ], Predicted Vowel: u
# Formants: [ 386.71875 2210.9375 ], Predicted Vowel: e
# Formants: [433.59375 800.78125], Predicted Vowel: u
# Formants: [ 484.375   2082.03125], Predicted Vowel: e
# Formants: [ 468.75    2019.53125], Predicted Vowel: e
# Formants: [468.75    878.90625], Predicted Vowel: u
# Formants: [ 695.3125  1152.34375], Predicted Vowel: a
# Formants: [ 695.3125 1367.1875], Predicted Vowel: a
# Formants: [363.28125 707.03125], Predicted Vowel: u
# Formants: [367.1875  761.71875], Predicted Vowel: u
# Formants: [320.3125  675.78125], Predicted Vowel: u
# Formants: [ 410.15625 2136.71875], Predicted Vowel: e
# Formants: [ 757.8125  1011.71875], Predicted Vowel: a
# Formants: [ 714.84375 1132.8125 ], Predicted Vowel: a
# Formants: [ 632.8125  1152.34375], Predicted Vowel: a
# Formants: [371.09375 800.78125], Predicted Vowel: u
# Formants: [ 851.5625 1164.0625], Predicted Vowel: a
# Formants: [296.875   753.90625], Predicted Vowel: u
# Formants: [ 476.5625  2074.21875], Predicted Vowel: e
# Formants: [ 425.78125 2027.34375], Predicted Vowel: e
# Formants: [ 382.8125  1933.59375], Predicted Vowel: e
# Formants: [460.9375 882.8125], Predicted Vowel: u
# Formants: [375.    765.625], Predicted Vowel: u
# Formants: [347.65625 710.9375 ], Predicted Vowel: u
# Formants: [ 769.53125 1078.125  ], Predicted Vowel: a
# Formants: [ 785.15625 1148.4375 ], Predicted Vowel: a
# Formants: [  3.90625 324.21875], Predicted Vowel: u
# Formants: [ 765.625   1105.46875], Predicted Vowel: a
# Formants: [ 460.9375 2023.4375], Predicted Vowel: e
# Formants: [ 691.40625 1046.875  ], Predicted Vowel: a
# Formants: [ 785.15625 1167.96875], Predicted Vowel: a
# Formants: [367.1875 703.125 ], Predicted Vowel: u
# Formants: [332.03125 636.71875], Predicted Vowel: u
# Formants: [ 753.90625 1289.0625 ], Predicted Vowel: a
# Formants: [ 726.5625  1152.34375], Predicted Vowel: a
# Formants: [ 753.90625 1148.4375 ], Predicted Vowel: a
# Formants: [ 484.375   2105.46875], Predicted Vowel: e
# Classifier Accuracy: 98.61%
# C:\Users\saura\AppData\Local\Temp\ipykernel_23704\387110850.py:52: RuntimeWarning: divide by zero encountered in log
#   likelihood = np.log(multivariate_gaussian_pdf(x, means[c], covariances[c]))

# %% [markdown]
# # 4. for Full Co-variance Matrix & having different for each classes : RWD

# %%
import numpy as np

# Function to compute the determinant of a matrix
def determinant(matrix):
    return np.linalg.det(matrix)

# Function to compute the inverse of a matrix
def inverse(matrix):
    return np.linalg.inv(matrix)

# Function to compute the multivariate Gaussian PDF manually
def multivariate_gaussian(x, mean, cov):
    d = len(x)
    cov_inv = inverse(cov)
    cov_det = determinant(cov)
    norm_factor = 1.0 / (np.power(2 * np.pi, d / 2) * np.sqrt(cov_det))
    x_mu = np.array(x - mean)
    exponent = -0.5 * np.dot(np.dot(x_mu.T, cov_inv), x_mu)
    return norm_factor * np.exp(exponent)

# Load the data from the files
class1_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class1.txt')
class2_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class2.txt')
class3_data = np.loadtxt('C:\\Users\\saura\\Desktop\\assignment spr\\assignment1\\MY_data_set\\Group03\\Group03\\rd_group3\\Class3.txt')

# Split the data into training and test sets (70% train, 30% test)
def train_test_split(data, test_size=0.3, random_state=42):
    np.random.seed(random_state)
    indices = np.random.permutation(len(data))
    split_idx = int(len(data) * (1 - test_size))
    return data[indices[:split_idx]], data[indices[split_idx:]]

train1, test1 = train_test_split(class1_data)
train2, test2 = train_test_split(class2_data)
train3, test3 = train_test_split(class3_data)

# Calculate the mean and full covariance matrix for each class
mean1 = np.mean(train1, axis=0)
mean2 = np.mean(train2, axis=0)
mean3 = np.mean(train3, axis=0)

cov1 = np.cov(train1, rowvar=False)
cov2 = np.cov(train2, rowvar=False)
cov3 = np.cov(train3, rowvar=False)

# Define the class priors (assuming equal priors here)
priors = [1/3, 1/3, 1/3]

# Define a function to compute the posterior probabilities using Bayes' theorem
def bayes_classifier(x, means, covariances, priors):
    posteriors = []
    for i, mean in enumerate(means):
        likelihood = multivariate_gaussian(x, mean, covariances[i])
        posterior = likelihood * priors[i]
        posteriors.append(posterior)
    return np.argmax(posteriors)

# Combine the training data and means
train_data = [train1, train2, train3]
means = [mean1, mean2, mean3]
covariances = [cov1, cov2, cov3]

# Testing the classifier
test_data = np.vstack((test1, test2, test3))
true_labels = np.array([0]*len(test1) + [1]*len(test2) + [2]*len(test3))

predicted_labels = [bayes_classifier(x, means, covariances, priors) for x in test_data]

# Calculate accuracy
accuracy = np.mean(predicted_labels == true_labels)
print(f"Classifier Accuracy: {accuracy * 100:.2f}%")

# Data visualization and decision boundary plotting
# Plot the decision boundary by creating a grid of points
x_min, x_max = test_data[:, 0].min() - 1, test_data[:, 0].max() + 1
y_min, y_max = test_data[:, 1].min() - 1, test_data[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200), np.linspace(y_min, y_max, 200))
grid = np.c_[xx.ravel(), yy.ravel()]

# Predict the class for each point in the grid
grid_predictions = np.array([bayes_classifier(point, means, covariances, priors) for point in grid])
grid_predictions = grid_predictions.reshape(xx.shape)

# Plotting
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.contourf(xx, yy, grid_predictions, alpha=0.3, cmap='coolwarm')

plt.scatter(train1[:, 0], train1[:, 1], c='blue', label='Class 1', edgecolors='k', marker='o')
plt.scatter(train2[:, 0], train2[:, 1], c='red', label='Class 2', edgecolors='k', marker='s')
plt.scatter(train3[:, 0], train3[:, 1], c='green', label='Class 3', edgecolors='k', marker='^')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Bayes Classifier Decision Boundary (Full Covariance)')
plt.legend()
plt.show()
# Out:
# Classifier Accuracy: 98.32%
