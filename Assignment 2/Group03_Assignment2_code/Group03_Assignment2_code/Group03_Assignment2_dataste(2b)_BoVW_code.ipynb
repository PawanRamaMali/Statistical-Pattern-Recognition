# %% [markdown]
# # Step 1 :Feature Extraction Using Bag_of_visual_word

# %%
import os
import numpy as np
import cv2
from sklearn.cluster import KMeans

# Function to extract 24-dimensional color histogram features from patches
def extract_patch_histogram(patch, bins=(8, 8, 8)):
    hist_r = cv2.calcHist([patch], [0], None, [bins[0]], [0, 256]).flatten()  # Red channel
    hist_g = cv2.calcHist([patch], [1], None, [bins[1]], [0, 256]).flatten()  # Green channel
    hist_b = cv2.calcHist([patch], [2], None, [bins[2]], [0, 256]).flatten()  # Blue channel
    
    hist_r /= np.sum(hist_r)
    hist_g /= np.sum(hist_g)
    hist_b /= np.sum(hist_b)
    
    feature_vector = np.concatenate([hist_r, hist_g, hist_b])
    return feature_vector

# Extract features from 32x32 patches
def extract_image_features(image, patch_size=(32, 32), bins=(8, 8, 8)):
    img_h, img_w, _ = image.shape
    all_patches_features = []
    
    for i in range(0, img_h, patch_size[0]):
        for j in range(0, img_w, patch_size[1]):
            patch = image[i:i+patch_size[0], j:j+patch_size[1]]
            if patch.shape[0] == patch_size[0] and patch.shape[1] == patch_size[1]:
                patch_features = extract_patch_histogram(patch, bins)
                all_patches_features.append(patch_features)
    
    return np.array(all_patches_features)

# Extract BoVW feature for a single image
def extract_bovw_feature(image_path, kmeans_model, num_clusters=32):
    image = cv2.imread(image_path)
    if image is not None:
        features = extract_image_features(image)
        cluster_assignments = kmeans_model.predict(features)
        
        # Count how many features fall into each of the 32 clusters
        bovw_feature = np.histogram(cluster_assignments, bins=np.arange(0, num_clusters + 1))[0]
        
        # Normalize the BoVW vector
        bovw_feature = bovw_feature / np.sum(bovw_feature)
        return bovw_feature

# Process and save BoVW features for the entire dataset
def process_bovw_features_for_dataset(dataset_folder, kmeans_model, output_folder, num_clusters=32):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    class_folders = os.listdir(dataset_folder)
    for class_name in class_folders:
        class_folder_path = os.path.join(dataset_folder, class_name)
        output_class_folder = os.path.join(output_folder, class_name)
        if not os.path.exists(output_class_folder):
            os.makedirs(output_class_folder)
        
        for image_name in os.listdir(class_folder_path):
            image_path = os.path.join(class_folder_path, image_name)
            bovw_feature = extract_bovw_feature(image_path, kmeans_model, num_clusters)
            output_file = os.path.join(output_class_folder, f"{image_name.split('.')[0]}_bovw.npy")
            np.save(output_file, bovw_feature)
            print(f"Processed and saved BoVW features for {image_name}")

# Example usage for processing the train and test datasets
train_folder = r'3-class-scene-image-dataset/train'
test_folder = r'3-class-scene-image-dataset/test'
output_train_bovw = r'3-class-scene-image-dataset/output_train_features_bovw'
output_test_bovw = r'3-class-scene-image-dataset/output_test_features_bovw'

# Assuming 24-dimensional histogram features have already been extracted for all training images
# Load all the training 24-dimensional features to apply K-means clustering
all_train_features = []
for class_name in os.listdir(train_folder):
    class_folder = os.path.join(train_folder, class_name)
    for image_name in os.listdir(class_folder):
        image_path = os.path.join(class_folder, image_name)
        image = cv2.imread(image_path)  # Load the image using OpenCV
    if image is not None:
        features = extract_image_features(image)  # Extract the 24-dimensional color histogram features from the image
        all_train_features.append(features)
        all_train_features.append(features)

all_train_features = np.vstack(all_train_features)  # Combine all training features

# Perform K-means clustering on the 24-dimensional features of all classes
num_clusters = 32
kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)
kmeans_model.fit(all_train_features)

# Process and save BoVW features for training and test sets
print("Processing BoVW features for training set...")
process_bovw_features_for_dataset(train_folder, kmeans_model, output_train_bovw, num_clusters)

print("Processing BoVW features for test set...")
process_bovw_features_for_dataset(test_folder, kmeans_model, output_test_bovw, num_clusters)
# Out:
# Processing BoVW features for training set...
# Processed and saved BoVW features for sun_aagvwgntclshghai.jpg
# Processed and saved BoVW features for sun_aamlzecjkxlnoedl.jpg
# Processed and saved BoVW features for sun_aarrlvxxrjxftsuu.jpg
# Processed and saved BoVW features for sun_abjxfjcrqxjhbkhi.jpg
# Processed and saved BoVW features for sun_abybmfbnmlztrjpm.jpg
# Processed and saved BoVW features for sun_acrbvetgiwtbvpid.jpg
# Processed and saved BoVW features for sun_acrvwdwcnqgbvcbi.jpg
# Processed and saved BoVW features for sun_adlsavfxcjkctdfu.jpg
# Processed and saved BoVW features for sun_aeylitslkauqmnqw.jpg
# Processed and saved BoVW features for sun_afqgbxrmirjsvmid.jpg
# Processed and saved BoVW features for sun_afxnftrhigdckaaa.jpg
# Processed and saved BoVW features for sun_aghkmbqrsfmpshxw.jpg
# Processed and saved BoVW features for sun_aglxrcfjrogfzdhm.jpg
# Processed and saved BoVW features for sun_ahtzdwjqixilslrl.jpg
# Processed and saved BoVW features for sun_airytsbhvjoeuqnk.jpg
# Processed and saved BoVW features for sun_aiuhwofaknavsqzr.jpg
# Processed and saved BoVW features for sun_akbydxhnubvnjymf.jpg
# Processed and saved BoVW features for sun_akdikawjhayiecma.jpg
# Processed and saved BoVW features for sun_akgdctkuexuapbnq.jpg
# Processed and saved BoVW features for sun_aknlbkdbkblqjpcg.jpg
# Processed and saved BoVW features for sun_alfmwlhgekogikbi.jpg
# Processed and saved BoVW features for sun_almgpgsljkensfbb.jpg
# Processed and saved BoVW features for sun_amaitcyodsfflkgk.jpg
# Processed and saved BoVW features for sun_amkvqkozgqywhfgw.jpg
# Processed and saved BoVW features for sun_antpdimsgaumhkzj.jpg
# Processed and saved BoVW features for sun_anzoyntpuzkyzgyn.jpg
# Processed and saved BoVW features for sun_aojdlarxknlgavli.jpg
# Processed and saved BoVW features for sun_aptyzmluwzhdusmc.jpg
# Processed and saved BoVW features for sun_apxhgpmlykvgxnze.jpg
# Processed and saved BoVW features for sun_aqpppkkoqczrdksj.jpg
# Processed and saved BoVW features for sun_arebfbeocihdehdc.jpg
# Processed and saved BoVW features for sun_arqegunvvfldtqds.jpg
# Processed and saved BoVW features for sun_aryrtpbehyqzvnvp.jpg
# Processed and saved BoVW features for sun_asdfdvkuyuolqmwb.jpg
# Processed and saved BoVW features for sun_ategwevtllxpobot.jpg
# Processed and saved BoVW features for sun_atrjnvltlivtzznr.jpg
# Processed and saved BoVW features for sun_auglgxcbcquqoysr.jpg
# Processed and saved BoVW features for sun_aukkmetnkwxwhwil.jpg
# Processed and saved BoVW features for sun_aumcjogqstlttpej.jpg
# Processed and saved BoVW features for sun_avgiabmlryowstua.jpg
# Processed and saved BoVW features for sun_avwrcvziukipjbix.jpg
# Processed and saved BoVW features for sun_avxtaljworlgtfgi.jpg
# Processed and saved BoVW features for sun_awaaqfhyfnlmkhpq.jpg
# Processed and saved BoVW features for sun_awjouldhduoibblc.jpg
# Processed and saved BoVW features for sun_awjxwjhqqizdegbd.jpg
# Processed and saved BoVW features for sun_axdmfmzdmhqwjjpf.jpg
# Processed and saved BoVW features for sun_axlvfjcqvtemwgyb.jpg
# Processed and saved BoVW features for sun_axossqupetrgehjt.jpg
# Processed and saved BoVW features for sun_aykzmokursdxtcqj.jpg
# Processed and saved BoVW features for sun_azbjkelxhqmwhikj.jpg
# Processed and saved BoVW features for sun_aackmxuaumbyjrvf.jpg
# Processed and saved BoVW features for sun_aaftvelcelybxkhs.jpg
# Processed and saved BoVW features for sun_aangxwznfqpugceb.jpg
# Processed and saved BoVW features for sun_aawayyqpzkeynmwu.jpg
# Processed and saved BoVW features for sun_abehcagumefhwepv.jpg
# Processed and saved BoVW features for sun_abicjjustshspbzc.jpg
# Processed and saved BoVW features for sun_abjellydogjafulc.jpg
# Processed and saved BoVW features for sun_acbvpqukiofgvynm.jpg
# Processed and saved BoVW features for sun_acilupxslewqgtyw.jpg
# Processed and saved BoVW features for sun_acpberzhngstmamb.jpg
# Processed and saved BoVW features for sun_adgvtrlznhpbcyjb.jpg
# Processed and saved BoVW features for sun_adinqjwrrknsvuhl.jpg
# Processed and saved BoVW features for sun_aeepugixfpzpylrv.jpg
# Processed and saved BoVW features for sun_aefmeorznegoepui.jpg
# Processed and saved BoVW features for sun_aegeonamiuzihito.jpg
# Processed and saved BoVW features for sun_aehkklrojfaovroy.jpg
# Processed and saved BoVW features for sun_aetuzbtadkfjplvz.jpg
# Processed and saved BoVW features for sun_afblakizhfyfgexw.jpg
# Processed and saved BoVW features for sun_afdyvswxxniijwqd.jpg
# Processed and saved BoVW features for sun_agpwvfrihiyvgvim.jpg
# Processed and saved BoVW features for sun_agqntkcnzrdcfyqz.jpg
# Processed and saved BoVW features for sun_agtmekdzuythzgsq.jpg
# Processed and saved BoVW features for sun_ahhvaejtcvichkpm.jpg
# Processed and saved BoVW features for sun_ajpchrddlwjqxslx.jpg
# Processed and saved BoVW features for sun_ajupbdihrwdcwgsh.jpg
# Processed and saved BoVW features for sun_akahvgfxgydyyxuy.jpg
# Processed and saved BoVW features for sun_akihpnhiblchzhgq.jpg
# Processed and saved BoVW features for sun_aksxiwxhzullzvla.jpg
# Processed and saved BoVW features for sun_almqhexytbgvxtfc.jpg
# Processed and saved BoVW features for sun_amghtjzoujyzurft.jpg
# Processed and saved BoVW features for sun_aocnnmjnhxawuivv.jpg
# Processed and saved BoVW features for sun_aofxjrllayoyuobq.jpg
# Processed and saved BoVW features for sun_aomucvhaclqgskmi.jpg
# Processed and saved BoVW features for sun_aosiagfhrdhnayvm.jpg
# Processed and saved BoVW features for sun_aqbyldrghvobxptj.jpg
# Processed and saved BoVW features for sun_arfesnaxdxwpjcin.jpg
# Processed and saved BoVW features for sun_arfieglhnmdapnrj.jpg
# Processed and saved BoVW features for sun_arvbwpytrtowibep.jpg
# Processed and saved BoVW features for sun_asgixjtedklbawgm.jpg
# Processed and saved BoVW features for sun_atnydzegnnnsodjs.jpg
# Processed and saved BoVW features for sun_avpvivtjynwhydrh.jpg
# Processed and saved BoVW features for sun_awbkzsgvdfjtweuz.jpg
# Processed and saved BoVW features for sun_aweouoygadstrmai.jpg
# Processed and saved BoVW features for sun_awmutccuioflhfti.jpg
# Processed and saved BoVW features for sun_axnpvydzwzwjawdx.jpg
# Processed and saved BoVW features for sun_ayvyivfyqxdiqcjz.jpg
# Processed and saved BoVW features for sun_azhulnhvqosjhbas.jpg
# Processed and saved BoVW features for sun_azpmxnrlzbqivdlb.jpg
# Processed and saved BoVW features for sun_azqqcdprlmrwqcts.jpg
# Processed and saved BoVW features for sun_boznvhxxhtfpldpr.jpg
# Processed and saved BoVW features for sun_aabpsmafrtneeadl.jpg
# Processed and saved BoVW features for sun_aafvyefdfobptgrz.jpg
# Processed and saved BoVW features for sun_aazufrgymjxluzjo.jpg
# Processed and saved BoVW features for sun_abbqsmpgzwrfmjxg.jpg
# Processed and saved BoVW features for sun_abgifrznoippetrg.jpg
# Processed and saved BoVW features for sun_acvovsrkuqmypydj.jpg
# Processed and saved BoVW features for sun_aefcbrgrtkkhfznu.jpg
# Processed and saved BoVW features for sun_aekqnnackgxerrjn.jpg
# Processed and saved BoVW features for sun_aeueepyxdhmzhgoa.jpg
# Processed and saved BoVW features for sun_aexorgchctkcbhiq.jpg
# Processed and saved BoVW features for sun_aeyjnybbygaaonmh.jpg
# Processed and saved BoVW features for sun_afcagahirnkxvaja.jpg
# Processed and saved BoVW features for sun_afxxlyvgmhxzkxjs.jpg
# Processed and saved BoVW features for sun_agejojvttluyffmk.jpg
# Processed and saved BoVW features for sun_agjqlblmiamwobjj.jpg
# Processed and saved BoVW features for sun_agqptvebrkgytbfi.jpg
# Processed and saved BoVW features for sun_aicltyhfaazmpqtt.jpg
# Processed and saved BoVW features for sun_aitvbhevbkjlnbqw.jpg
# Processed and saved BoVW features for sun_ajcnfezfvmclnyac.jpg
# Processed and saved BoVW features for sun_ajohvhiylzpdcryv.jpg
# Processed and saved BoVW features for sun_ajruhveolfpfjvvj.jpg
# Processed and saved BoVW features for sun_ajswveykgvwddpqd.jpg
# Processed and saved BoVW features for sun_ajtvpetsnpaowbto.jpg
# Processed and saved BoVW features for sun_akobbzgscgahkypx.jpg
# Processed and saved BoVW features for sun_aktwjrhpbihxnxhq.jpg
# Processed and saved BoVW features for sun_akwoeqhbppkvumyv.jpg
# Processed and saved BoVW features for sun_albvrbzxtbhlfooz.jpg
# Processed and saved BoVW features for sun_alepnfaubsfdgzar.jpg
# Processed and saved BoVW features for sun_anszcgxfcpqjvfny.jpg
# Processed and saved BoVW features for sun_aowzthgywqfumjcg.jpg
# Processed and saved BoVW features for sun_apinwducjegkiqxk.jpg
# Processed and saved BoVW features for sun_apxuuyzeafxerpie.jpg
# Processed and saved BoVW features for sun_aqftctjxicgethmn.jpg
# Processed and saved BoVW features for sun_aqqqrpavpjkngryl.jpg
# Processed and saved BoVW features for sun_arvzxhlyywcanvyu.jpg
# Processed and saved BoVW features for sun_asvnyjcbsipjnsre.jpg
# Processed and saved BoVW features for sun_aswgzhhypdloknko.jpg
# Processed and saved BoVW features for sun_auaqjvijijwnojgv.jpg
# Processed and saved BoVW features for sun_audzwsdhislqmcvy.jpg
# Processed and saved BoVW features for sun_auyjcmqmsxiatjtg.jpg
# Processed and saved BoVW features for sun_awafckiuiwdagofk.jpg
# Processed and saved BoVW features for sun_axjdhjaiwsugmxru.jpg
# Processed and saved BoVW features for sun_axqnowuutloxkcsp.jpg
# Processed and saved BoVW features for sun_axvdfabagcfcrjdn.jpg
# Processed and saved BoVW features for sun_aykzcanmbpokcood.jpg
# Processed and saved BoVW features for sun_ayorrcegxiolwxng.jpg
# Processed and saved BoVW features for sun_ayparszjadedxjia.jpg
# Processed and saved BoVW features for sun_ayqetykpphjpuabg.jpg
# Processed and saved BoVW features for sun_bejituvblxjrssxl.jpg
# Processed and saved BoVW features for sun_beroqgzewiqbdocz.jpg
# Processing BoVW features for test set...
# Processed and saved BoVW features for sun_aaestfykdspfjxqz.jpg
# Processed and saved BoVW features for sun_aajgmzsvuhejexcq.jpg
# Processed and saved BoVW features for sun_aaqfmkvdwukffrst.jpg
# Processed and saved BoVW features for sun_acbeefkxpymwevpk.jpg
# Processed and saved BoVW features for sun_acghfkorvlqvksjz.jpg
# Processed and saved BoVW features for sun_ackdwnmnaehpqggg.jpg
# Processed and saved BoVW features for sun_ackzydggopidfvhd.jpg
# Processed and saved BoVW features for sun_acuexwlypmvysydi.jpg
# Processed and saved BoVW features for sun_acyjrzznztmroglp.jpg
# Processed and saved BoVW features for sun_aczyhutikhgtlnhk.jpg
# Processed and saved BoVW features for sun_adcpwszvjhmjgzdb.jpg
# Processed and saved BoVW features for sun_adwfwvslgbctxwkx.jpg
# Processed and saved BoVW features for sun_aeevojrozcqhtqgc.jpg
# Processed and saved BoVW features for sun_ahvtjbhivntafhxz.jpg
# Processed and saved BoVW features for sun_aicmpgyflyssqvky.jpg
# Processed and saved BoVW features for sun_ainaqbcbmukvybcj.jpg
# Processed and saved BoVW features for sun_ajdgttnlsffrzlvn.jpg
# Processed and saved BoVW features for sun_ajhvdzdscjkjzath.jpg
# Processed and saved BoVW features for sun_ajwacughhjxewlvz.jpg
# Processed and saved BoVW features for sun_akbroihotcraybvn.jpg
# Processed and saved BoVW features for sun_akbuisxsqiyfgjnw.jpg
# Processed and saved BoVW features for sun_akcxxbgqrapnmrqt.jpg
# Processed and saved BoVW features for sun_akfqqtdmkhvbevga.jpg
# Processed and saved BoVW features for sun_akpdbwazawgjppjy.jpg
# Processed and saved BoVW features for sun_aktxaltontyvqota.jpg
# Processed and saved BoVW features for sun_alrbwinlajjslmwe.jpg
# Processed and saved BoVW features for sun_alyakkizvmfscmlr.jpg
# Processed and saved BoVW features for sun_aobzjrxxrpeklywd.jpg
# Processed and saved BoVW features for sun_aodtfpoxdoavijdz.jpg
# Processed and saved BoVW features for sun_arqftsaavloikzcu.jpg
# Processed and saved BoVW features for sun_asdpywyimdfmumkh.jpg
# Processed and saved BoVW features for sun_ashjgsspyetcvpqc.jpg
# Processed and saved BoVW features for sun_atbyusklawegwiiq.jpg
# Processed and saved BoVW features for sun_atitaedukmimiozr.jpg
# Processed and saved BoVW features for sun_atqpcjggyhbeqyyc.jpg
# Processed and saved BoVW features for sun_auacrknnpbhjfbbw.jpg
# Processed and saved BoVW features for sun_augenxtxecqysxcv.jpg
# Processed and saved BoVW features for sun_augwhqyrmoilsjbi.jpg
# Processed and saved BoVW features for sun_auvwkdwoulmwacyv.jpg
# Processed and saved BoVW features for sun_avpzdyffxslyxtez.jpg
# Processed and saved BoVW features for sun_avrxmzjwgzdwxoye.jpg
# Processed and saved BoVW features for sun_awfsyotdyjpvaxxr.jpg
# Processed and saved BoVW features for sun_awugifynqpycseqc.jpg
# Processed and saved BoVW features for sun_axqjmnoybtmijszw.jpg
# Processed and saved BoVW features for sun_axtzggujhstolptu.jpg
# Processed and saved BoVW features for sun_ayecsidneqlekrsx.jpg
# Processed and saved BoVW features for sun_aygrtwrwfezqjizr.jpg
# Processed and saved BoVW features for sun_aypwnlepbscmkvof.jpg
# Processed and saved BoVW features for sun_ayxobrnajtjaxbjd.jpg
# Processed and saved BoVW features for sun_azdoopzgfiafkayr.jpg
# Processed and saved BoVW features for sun_aaookxeymqefesal.jpg
# Processed and saved BoVW features for sun_aaqdsbrpbdabfsbf.jpg
# Processed and saved BoVW features for sun_acecyziibcihwzoa.jpg
# Processed and saved BoVW features for sun_acllxzfyqauwsehk.jpg
# Processed and saved BoVW features for sun_adjxqctzulwziqbn.jpg
# Processed and saved BoVW features for sun_advxqepgmiwktola.jpg
# Processed and saved BoVW features for sun_adwesqwixmfqxgtx.jpg
# Processed and saved BoVW features for sun_aecciygrclivrymn.jpg
# Processed and saved BoVW features for sun_aehmwnhywonrztaf.jpg
# Processed and saved BoVW features for sun_aejgohjxdlnnzztz.jpg
# Processed and saved BoVW features for sun_afozvdelwolgkiii.jpg
# Processed and saved BoVW features for sun_agjrtosqpvfypfbo.jpg
# Processed and saved BoVW features for sun_ahoryetnogywzojj.jpg
# Processed and saved BoVW features for sun_ahprpgqzhdsgfpxd.jpg
# Processed and saved BoVW features for sun_aixxkdwodcmoyzjg.jpg
# Processed and saved BoVW features for sun_ajamewtjtshzjzee.jpg
# Processed and saved BoVW features for sun_ajniqqmevovpigjc.jpg
# Processed and saved BoVW features for sun_akapvnwljqiszigh.jpg
# Processed and saved BoVW features for sun_alcjyozpqdyuwjkh.jpg
# Processed and saved BoVW features for sun_alharewbbgteazev.jpg
# Processed and saved BoVW features for sun_alleoakvlilxlkip.jpg
# Processed and saved BoVW features for sun_amggaalxpfcdhtwb.jpg
# Processed and saved BoVW features for sun_amhjsfbfnjzpfmts.jpg
# Processed and saved BoVW features for sun_ammqkoaojhblscfk.jpg
# Processed and saved BoVW features for sun_amnhyskdrvvhjxch.jpg
# Processed and saved BoVW features for sun_anoysehdxqvtblch.jpg
# Processed and saved BoVW features for sun_anuccyypakddkvpd.jpg
# Processed and saved BoVW features for sun_anuvwfskoyytyzff.jpg
# Processed and saved BoVW features for sun_apdhbrkggbsaqdjy.jpg
# Processed and saved BoVW features for sun_aphtinllftzevfpn.jpg
# Processed and saved BoVW features for sun_apjlqamjqainvtex.jpg
# Processed and saved BoVW features for sun_appkuavbzhxwbiox.jpg
# Processed and saved BoVW features for sun_appwllojufniahga.jpg
# Processed and saved BoVW features for sun_arskefblxexvzgic.jpg
# Processed and saved BoVW features for sun_asbrjmrbzfqirlim.jpg
# Processed and saved BoVW features for sun_asqsdkeavvmmjywb.jpg
# Processed and saved BoVW features for sun_assoogmkirrqttps.jpg
# Processed and saved BoVW features for sun_atdxtruuizwzjadt.jpg
# Processed and saved BoVW features for sun_atzrhbcvxuyemxoe.jpg
# Processed and saved BoVW features for sun_aucxledgylowriby.jpg
# Processed and saved BoVW features for sun_aujzbsrigtiovibc.jpg
# Processed and saved BoVW features for sun_auzndqbgyfodsewj.jpg
# Processed and saved BoVW features for sun_avtegqjsayfszziy.jpg
# Processed and saved BoVW features for sun_awrkbvmnpdyrnaxy.jpg
# Processed and saved BoVW features for sun_axecxurrknktsubr.jpg
# Processed and saved BoVW features for sun_axogkymwdlhoqovu.jpg
# Processed and saved BoVW features for sun_axvnolpqjlggbtrw.jpg
# Processed and saved BoVW features for sun_ayjctazptmrezpal.jpg
# Processed and saved BoVW features for sun_ayssmvnrwfowflaz.jpg
# Processed and saved BoVW features for sun_azffqakxecywinrs.jpg
# Processed and saved BoVW features for sun_aacgdhdsnjzxcgax.jpg
# Processed and saved BoVW features for sun_aadeopqdhgrobvqm.jpg
# Processed and saved BoVW features for sun_aapbvlsxbfbdihfb.jpg
# Processed and saved BoVW features for sun_abpfulsvesxynnwz.jpg
# Processed and saved BoVW features for sun_acgmbzycrhxtmjdh.jpg
# Processed and saved BoVW features for sun_acwykadkcgeddmxc.jpg
# Processed and saved BoVW features for sun_addirejroxghtmrm.jpg
# Processed and saved BoVW features for sun_aeurfpqzwflmkdxo.jpg
# Processed and saved BoVW features for sun_agoxuyhyugwuuekn.jpg
# Processed and saved BoVW features for sun_agtcwwbzxopcbizr.jpg
# Processed and saved BoVW features for sun_ahhgdoblnheoxcpp.jpg
# Processed and saved BoVW features for sun_ahxyrihxxtesytxs.jpg
# Processed and saved BoVW features for sun_aidqojfeowvnvsyn.jpg
# Processed and saved BoVW features for sun_aikqrdbjlewabdni.jpg
# Processed and saved BoVW features for sun_ajofgorwpatbxtej.jpg
# Processed and saved BoVW features for sun_ajtydyeuepreayhz.jpg
# Processed and saved BoVW features for sun_akcycfgptrmdmbik.jpg
# Processed and saved BoVW features for sun_akehcuvnzdqbcjtr.jpg
# Processed and saved BoVW features for sun_akfqcrrqpbzjsqob.jpg
# Processed and saved BoVW features for sun_akhdehitquntyszv.jpg
# Processed and saved BoVW features for sun_akhwozmuqyvaayfl.jpg
# Processed and saved BoVW features for sun_akuftfwcepfplhsh.jpg
# Processed and saved BoVW features for sun_alabjcqbzbtvvtcp.jpg
# Processed and saved BoVW features for sun_allbzlcdjvazzghj.jpg
# Processed and saved BoVW features for sun_alpkhxvjuxlgysvh.jpg
# Processed and saved BoVW features for sun_alufucueluzcbpos.jpg
# Processed and saved BoVW features for sun_amatwvgcfyzuynms.jpg
# Processed and saved BoVW features for sun_amnipwocjnqfrdds.jpg
# Processed and saved BoVW features for sun_anyoomviykbcfzps.jpg
# Processed and saved BoVW features for sun_aoyjfyrnyczrgtvw.jpg
# Processed and saved BoVW features for sun_apnagbvvtlhmnidd.jpg
# Processed and saved BoVW features for sun_aqbjeflkufpnvuvq.jpg
# Processed and saved BoVW features for sun_aqhbnjejdmwfpifm.jpg
# Processed and saved BoVW features for sun_arhzsylsqilqjlrg.jpg
# Processed and saved BoVW features for sun_aripdbqeoszauhdj.jpg
# Processed and saved BoVW features for sun_arxtjqriutqcoorj.jpg
# Processed and saved BoVW features for sun_arzgxrphmdibfvvn.jpg
# Processed and saved BoVW features for sun_asaihuvkcwnbsvej.jpg
# Processed and saved BoVW features for sun_asuedipgaiykcgyv.jpg
# Processed and saved BoVW features for sun_asxlyagnntbmtpii.jpg
# Processed and saved BoVW features for sun_atisekgpjwviikei.jpg
# Processed and saved BoVW features for sun_auoymymxfszqbypy.jpg
# Processed and saved BoVW features for sun_avcrkwrwsgjmrkht.jpg
# Processed and saved BoVW features for sun_avulsbgqrlagzdlp.jpg
# Processed and saved BoVW features for sun_awsmojrwqbdilqhg.jpg
# Processed and saved BoVW features for sun_axecntygrkzmnrbj.jpg
# Processed and saved BoVW features for sun_axnkcsintratvqlt.jpg
# Processed and saved BoVW features for sun_axxcegcnrsgeejff.jpg
# Processed and saved BoVW features for sun_azkxeypcmrlveciz.jpg
# Processed and saved BoVW features for sun_azvfdbhuvxduxapc.jpg

# %% [markdown]
# # Step 2a :visualizing BoVW Representation

# %%
import os
import numpy as np
import cv2
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Function to visualize BoVW histogram
def plot_bovw_histogram(bovw_feature, image_name, class_name):
    plt.bar(range(len(bovw_feature)), bovw_feature)
    plt.title(f'Bag of Visual Word Representation - {image_name} ({class_name})')
    plt.xlabel('Visual Word Index')
    plt.ylabel('Frequency')
    plt.show()

# Function to extract 24-dimensional color histogram features from patches (already defined)
def extract_patch_histogram(patch, bins=(8, 8, 8)):
    hist_r = cv2.calcHist([patch], [0], None, [bins[0]], [0, 256]).flatten()
    hist_g = cv2.calcHist([patch], [1], None, [bins[1]], [0, 256]).flatten()
    hist_b = cv2.calcHist([patch], [2], None, [bins[2]], [0, 256]).flatten()
    
    hist_r /= np.sum(hist_r)
    hist_g /= np.sum(hist_g)
    hist_b /= np.sum(hist_b)
    
    feature_vector = np.concatenate([hist_r, hist_g, hist_b])
    return feature_vector

# Function to extract features from 32x32 patches
def extract_image_features(image, patch_size=(32, 32), bins=(8, 8, 8)):
    img_h, img_w, _ = image.shape
    all_patches_features = []
    
    for i in range(0, img_h, patch_size[0]):
        for j in range(0, img_w, patch_size[1]):
            patch = image[i:i+patch_size[0], j:j+patch_size[1]]
            if patch.shape[0] == patch_size[0] and patch.shape[1] == patch_size[1]:
                patch_features = extract_patch_histogram(patch, bins)
                all_patches_features.append(patch_features)
    
    return np.array(all_patches_features)

# Function to extract BoVW features from an image
def extract_bovw_feature(image_path, kmeans_model, num_clusters=32):
    image = cv2.imread(image_path)
    if image is not None:
        features = extract_image_features(image)  # Extract 24-dimensional color histogram features from the image
        cluster_assignments = kmeans_model.predict(features)  # Assign to clusters
        
        # Count how many features fall into each of the 32 clusters
        bovw_feature = np.histogram(cluster_assignments, bins=np.arange(0, num_clusters + 1))[0]
        
        # Normalize the BoVW vector
        bovw_feature = bovw_feature / np.sum(bovw_feature)
        return bovw_feature

# Function to visualize BoVW features for two images from each class
def visualize_bovw_features(train_bovw_path, kmeans_model):
    class_folders = ['botanical_garden', 'bus_interior', 'elevator_shaft']
    
    for class_name in class_folders:
        class_folder = os.path.join(train_bovw_path, class_name)
        image_files = os.listdir(class_folder)[:2]  # First two images
        
        for image_file in image_files:
            image_path = os.path.join(class_folder, image_file)
            bovw_feature = extract_bovw_feature(image_path, kmeans_model)
            plot_bovw_histogram(bovw_feature, image_file, class_name)

# Step 1: Load BoVW features from the entire training set
def load_all_train_features(train_bovw_path):
    all_train_features = []
    
    for class_name in os.listdir(train_bovw_path):
        class_folder = os.path.join(train_bovw_path, class_name)
        for image_name in os.listdir(class_folder):
            # Load each image and extract its BoVW feature
            image_path = os.path.join(class_folder, image_name)
            image = cv2.imread(image_path)
            if image is not None:
                features = extract_image_features(image)  # Extract 24-dimensional color histogram features from the image
                all_train_features.extend(features)  # Add all patch features of the image
    
    return np.array(all_train_features)

# Example usage
train_bovw_path = r'3-class-scene-image-dataset/train'
num_clusters = 32

# Step 2: Load all BoVW features from the training dataset
all_train_features = load_all_train_features(train_bovw_path)

# Step 3: Fit KMeans model with the BoVW features from the entire training dataset
kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)
kmeans_model.fit(all_train_features)

# Step 4: Call the function to visualize BoVW features for first two images of each class
visualize_bovw_features(train_bovw_path, kmeans_model)

# %% [markdown]
# # Step 2b :K-Means Clustering on BoVW Feature on every class

# %%
from sklearn.cluster import KMeans
import numpy as np
import os

# Perform K-means clustering on BoVW features for each class
def perform_kmeans_class_by_class(train_bovw_path, num_clusters):
    class_folders = ['botanical_garden', 'bus_interior', 'elevator_shaft']
    kmeans_params = {}

    for class_name in class_folders:
        print(f"\nPerforming K-means clustering for class: {class_name} with K={num_clusters}")

        # Load the BoVW features for this class
        class_folder = os.path.join(train_bovw_path, class_name)
        class_features = np.vstack([np.load(os.path.join(class_folder, f)) for f in os.listdir(class_folder)])

        # Perform K-means clustering on the BoVW features
        kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)
        kmeans_model.fit(class_features)

        # Get the centroids (means) and calculate covariances for each cluster
        centroids = kmeans_model.cluster_centers_
        covariances = []
        labels = kmeans_model.labels_

        for i in range(num_clusters):
            cluster_points = class_features[labels == i]
            if len(cluster_points) > 1:
                covariance = np.cov(cluster_points.T)
            else:
                covariance = np.eye(class_features.shape[1])  # Identity matrix if cluster has one point
            covariances.append(covariance + np.eye(class_features.shape[1]) * 1e-6)  # Regularize covariance

        # Store the parameters (centroids and covariances)
        kmeans_params[class_name] = (centroids, covariances)

        # Print the K-means parameters
        print(f"K-means parameters for class {class_name}:")
        print("Centroids (Means):")
        for i, centroid in enumerate(centroids):
            print(f"Cluster {i + 1} centroid:\n{centroid}")

        print("\nCovariance Matrices:")
        for i, covariance in enumerate(covariances):
            print(f"Cluster {i + 1} covariance matrix:\n{covariance}")

    return kmeans_params

# Example usage for clustering with dynamic number of clusters (k)
train_bovw_path = '3-class-scene-image-dataset/output_train_features_bovw'
num_clusters = 1  # You can change this dynamically

# Perform K-means clustering on the BoVW features of each class
kmeans_params = perform_kmeans_class_by_class(train_bovw_path, num_clusters)
# Out:
# Performing K-means clustering for class: botanical_garden with K=1
# K-means parameters for class botanical_garden:
# Centroids (Means):
# Cluster 1 centroid:
# [2.47100108e-02 1.71556365e-04 4.06632048e-01 3.12377480e-04
#  2.03655938e-04 4.25083603e-02 1.33795833e-04 5.35824579e-03
#  9.33708887e-03 4.75913565e-02 4.96798085e-05 8.75011246e-05
#  4.37440377e-02 8.78374472e-04 2.51669672e-02 4.30527725e-02
#  1.59427045e-03 2.45531072e-03 1.00073106e-02 1.13605800e-02
#  1.40162030e-02 1.44936762e-03 6.33116892e-02 1.03744149e-01
#  3.79620419e-03 3.71610755e-03 9.60397317e-05 3.63483464e-03
#  6.37282013e-03 1.20788292e-02 9.26235554e-03 1.03166100e-01]
#
# Covariance Matrices:
# Cluster 1 covariance matrix:
# [[ 1.38975257e-03  9.86164654e-07 -1.16833512e-03 ...  1.66990799e-04
#    5.44655297e-06 -1.06514730e-03]
#  [ 9.86164654e-07  1.49668268e-06 -5.35553959e-07 ... -2.09869835e-06
#    1.74739854e-06  2.70087004e-06]
#  [-1.16833512e-03 -5.35553959e-07  2.82800791e-02 ... -3.47151830e-04
#   -9.67568014e-04 -9.38955721e-03]
#  ...
#  [ 1.66990799e-04 -2.09869835e-06 -3.47151830e-04 ...  5.39846544e-04
#    2.82117462e-05 -7.09868450e-04]
#  [ 5.44655297e-06  1.74739854e-06 -9.67568014e-04 ...  2.82117462e-05
#    2.42670641e-04  1.17553910e-04]
#  [-1.06514730e-03  2.70087004e-06 -9.38955721e-03 ... -7.09868450e-04
#    1.17553910e-04  1.04859713e-02]]
#
# Performing K-means clustering for class: bus_interior with K=1
# K-means parameters for class bus_interior:
# Centroids (Means):
# Cluster 1 centroid:
# [0.07444597 0.00381971 0.36307465 0.00477921 0.00117199 0.03839478
#  0.00250356 0.00104142 0.00404777 0.02945111 0.00147352 0.00131004
#  0.0240939  0.00658721 0.05960127 0.11806638 0.00330554 0.0121393
#  0.00847652 0.0220254  0.02747907 0.00310526 0.09811579 0.01123182
#  0.00208367 0.01427927 0.00195549 0.00365586 0.01258471 0.01968718
#  0.00309478 0.02291786]
#
# Covariance Matrices:
# Cluster 1 covariance matrix:
# [[ 3.78087342e-03 -5.99008853e-05 -6.31373034e-04 ...  1.63395130e-04
#   -6.12052247e-05 -7.20585743e-04]
#  [-5.99008853e-05  8.42775838e-05 -1.04399948e-04 ...  4.27400700e-05
#    1.42711233e-05 -5.62472664e-05]
#  [-6.31373034e-04 -1.04399948e-04  1.78909734e-02 ... -5.19688562e-04
#   -6.70565169e-05 -1.08672675e-03]
#  ...
#  [ 1.63395130e-04  4.27400700e-05 -5.19688562e-04 ...  5.04874383e-04
#   -1.00824698e-05 -6.38490459e-05]
#  [-6.12052247e-05  1.42711233e-05 -6.70565169e-05 ... -1.00824698e-05
#    9.31880154e-05  1.73649370e-06]
#  [-7.20585743e-04 -5.62472664e-05 -1.08672675e-03 ... -6.38490459e-05
#    1.73649370e-06  1.62321831e-03]]
#
# Performing K-means clustering for class: elevator_shaft with K=1
# K-means parameters for class elevator_shaft:
# Centroids (Means):
# Cluster 1 centroid:
# [9.46540141e-02 4.84363604e-04 2.50996714e-01 4.34282159e-03
#  1.85758514e-04 2.77030036e-02 0.00000000e+00 9.87855048e-04
#  1.02877988e-02 2.45565959e-02 2.88218979e-03 7.36665192e-04
#  5.53472952e-02 7.49252355e-03 2.60018740e-02 1.20035517e-01
#  6.26685915e-03 1.03673850e-02 1.69305103e-02 3.19724325e-02
#  1.79180310e-02 1.58153273e-03 1.50988946e-01 1.51469519e-02
#  1.31175806e-03 2.94070665e-02 3.80952381e-05 5.06576518e-04
#  2.14815266e-02 3.16734507e-02 2.79178067e-03 3.49221073e-02]
#
# Covariance Matrices:
# Cluster 1 covariance matrix:
# [[ 7.87417616e-03  3.48804662e-05  1.06623378e-03 ...  1.79138769e-04
#   -1.93116573e-04 -2.07885558e-03]
#  [ 3.48804662e-05  6.39950151e-06 -6.08088686e-05 ... -1.30146739e-05
#   -1.37318139e-06 -1.12637816e-05]
#  [ 1.06623378e-03 -6.08088686e-05  2.60874078e-02 ... -4.81523952e-04
#    1.27232693e-05 -1.97562212e-03]
#  ...
#  [ 1.79138769e-04 -1.30146739e-05 -4.81523952e-04 ...  1.23448344e-03
#    2.47800569e-05 -4.71122434e-04]
#  [-1.93116573e-04 -1.37318139e-06  1.27232693e-05 ...  2.47800569e-05
#    5.41777239e-05  7.16750598e-05]
#  [-2.07885558e-03 -1.12637816e-05 -1.97562212e-03 ... -4.71122434e-04
#    7.16750598e-05  2.77765195e-03]]

# %% [markdown]
# # Step 3 :Building the Bayes Classifier Using GMM

# %%
import numpy as np

# Function to compute the Gaussian probability density function (PDF)
def gaussian_pdf(x, mean, cov):
    n = len(x)
    epsilon = 1e-6  # Regularization to avoid singular matrices
    cov_det = np.linalg.det(cov + np.eye(n) * epsilon)  # Regularized determinant
    cov_inv = np.linalg.inv(cov + np.eye(n) * epsilon)  # Regularized inverse
    diff = x - mean
    exponent = -0.5 * np.dot(diff.T, np.dot(cov_inv, diff))
    return np.exp(exponent) / np.sqrt((2 * np.pi)**n * cov_det)

# Expectation step in EM algorithm (E-Step)
def expectation_step(X, means, covariances, weights):
    n, k = X.shape[0], len(means)
    responsibilities = np.zeros((n, k))
    for i in range(k):
        for j in range(n):
            responsibilities[j, i] = weights[i] * gaussian_pdf(X[j], means[i], covariances[i])
    
    responsibilities_sum = responsibilities.sum(axis=1, keepdims=True)
    responsibilities_sum[responsibilities_sum == 0] = 1e-6  # Avoid division by zero
    responsibilities /= responsibilities_sum
    return responsibilities

# Maximization step in EM algorithm (M-Step)
def maximization_step(X, responsibilities):
    n, d = X.shape
    k = responsibilities.shape[1]
    
    epsilon = 1e-6  # Regularization term to avoid division by zero
    weights = responsibilities.sum(axis=0) / (n + epsilon)
    means = np.dot(responsibilities.T, X) / (responsibilities.sum(axis=0)[:, None] + epsilon)
    
    covariances = []
    for i in range(k):
        diff = X - means[i]
        covariances.append(np.dot((responsibilities[:, i] * diff.T), diff) / (responsibilities[:, i].sum() + epsilon))
        covariances[i] += np.eye(d) * epsilon  # Regularize covariance
    
    return means, covariances, weights

# EM Algorithm to train the GMM
def gmm_em(X, k, means_init, covariances_init, max_iters=100, tol=1e-6):
    means = means_init
    covariances = covariances_init
    weights = np.ones(k) / k  # Initialize weights uniformly
    
    log_likelihoods = []
    
    for iteration in range(max_iters):
        # Expectation Step
        responsibilities = expectation_step(X, means, covariances, weights)
        
        # Maximization Step
        means, covariances, weights = maximization_step(X, responsibilities)
        
        # Log-Likelihood Calculation
        log_likelihood = np.sum([
            np.log(np.maximum(np.sum([weights[i] * gaussian_pdf(X[j], means[i], covariances[i]) for i in range(k)]), 1e-6))
            for j in range(len(X))
        ])
        log_likelihoods.append(log_likelihood)
        
        # Check for convergence
        if len(log_likelihoods) > 1 and np.abs(log_likelihoods[-1] - log_likelihoods[-2]) < tol:
            break
    
    return means, covariances, weights, log_likelihoods

# Train GMM on BoVW features for each class using K-means initialization
def train_gmm_class_by_class(train_bovw_path, kmeans_params):
    class_folders = ['botanical_garden', 'bus_interior', 'elevator_shaft']
    gmm_models = {}
    log_likelihoods_per_class = {}

    for class_name in class_folders:
        print(f"\nTraining GMM for class: {class_name}")
        
        # Load the BoVW features for this class
        class_folder = os.path.join(train_bovw_path, class_name)
        class_features = np.vstack([np.load(os.path.join(class_folder, f)) for f in os.listdir(class_folder)])
        
        # Get K-means initialization parameters for this class
        centroids, covariances = kmeans_params[class_name]
        k = len(centroids)  # Number of clusters from K-means
        
        # Train GMM using the EM algorithm with K-means initialization
        means, covariances, weights, log_likelihoods = gmm_em(class_features, k, centroids, covariances)
        
        # Store GMM parameters for this class
        gmm_models[class_name] = (means, covariances, weights)
        log_likelihoods_per_class[class_name] = log_likelihoods
        
        # Print final GMM parameters for the class
        print(f"\nFinal GMM Parameters for class {class_name}:")
        print("Means (Centroids):", means)
        print("Covariances:", covariances)
        print("Mixing Coefficients (Weights):", weights)

    return gmm_models, log_likelihoods_per_class

# Example usage
train_bovw_path = '3-class-scene-image-dataset/output_train_features_bovw'
gmm_models, log_likelihoods_per_class = train_gmm_class_by_class(train_bovw_path, kmeans_params)

# Plot log-likelihoods for each class
def plot_log_likelihoods(log_likelihoods_per_class):
    for class_name, log_likelihoods in log_likelihoods_per_class.items():
        plt.plot(log_likelihoods, label=f'Class: {class_name}')
    
    plt.title('Log-Likelihood vs Iterations for each class')
    plt.xlabel('Iteration')
    plt.ylabel('Log-Likelihood')
    plt.legend()
    plt.show()

plot_log_likelihoods(log_likelihoods_per_class)
# Out:
# Training GMM for class: botanical_garden
#
# Final GMM Parameters for class botanical_garden:
# Means (Centroids): [[2.47100103e-02 1.71556362e-04 4.06632040e-01 3.12377474e-04
#   2.03655934e-04 4.25083594e-02 1.33795830e-04 5.35824569e-03
#   9.33708869e-03 4.75913555e-02 4.96798075e-05 8.75011228e-05
#   4.37440368e-02 8.78374454e-04 2.51669667e-02 4.30527716e-02
#   1.59427041e-03 2.45531067e-03 1.00073104e-02 1.13605798e-02
#   1.40162027e-02 1.44936759e-03 6.33116880e-02 1.03744147e-01
#   3.79620412e-03 3.71610748e-03 9.60397298e-05 3.63483456e-03
#   6.37282000e-03 1.20788290e-02 9.26235536e-03 1.03166098e-01]]
# Covariances: [array([[ 1.36197749e-03,  9.66441342e-07, -1.14496840e-03, ...,
#          1.63650980e-04,  5.33762181e-06, -1.04384434e-03],
#        [ 9.66441342e-07,  1.48674902e-06, -5.24842869e-07, ...,
#         -2.05672434e-06,  1.71245053e-06,  2.64685259e-06],
#        [-1.14496840e-03, -5.24842869e-07,  2.77144970e-02, ...,
#         -3.40208786e-04, -9.48216635e-04, -9.20176588e-03],
#        ...,
#        [ 1.63650980e-04, -2.05672434e-06, -3.40208786e-04, ...,
#          5.29069602e-04,  2.76475107e-05, -6.95671067e-04],
#        [ 5.33762181e-06,  1.71245053e-06, -9.48216635e-04, ...,
#          2.76475107e-05,  2.37837223e-04,  1.15202829e-04],
#        [-1.04384434e-03,  2.64685259e-06, -9.20176588e-03, ...,
#         -6.95671067e-04,  1.15202829e-04,  1.02762717e-02]])]
# Mixing Coefficients (Weights): [0.99999998]
#
# Training GMM for class: bus_interior
#
# Final GMM Parameters for class bus_interior:
# Means (Centroids): [[0.07444597 0.00381971 0.36307465 0.00477921 0.00117199 0.03839478
#   0.00250356 0.00104142 0.00404777 0.02945111 0.00147352 0.00131004
#   0.0240939  0.00658721 0.05960126 0.11806637 0.00330554 0.0121393
#   0.00847652 0.02202539 0.02747907 0.00310526 0.09811579 0.01123182
#   0.00208367 0.01427927 0.00195549 0.00365586 0.01258471 0.01968718
#   0.00309478 0.02291786]]
# Covariances: [array([[ 3.70527588e-03, -5.87028665e-05, -6.18745561e-04, ...,
#          1.60127225e-04, -5.99811190e-05, -7.06174014e-04],
#        [-5.87028665e-05,  8.26120305e-05, -1.02311947e-04, ...,
#          4.18852677e-05,  1.39857006e-05, -5.51223200e-05],
#        [-6.18745561e-04, -1.02311947e-04,  1.75331735e-02, ...,
#         -5.09294780e-04, -6.57153853e-05, -1.06499219e-03],
#        ...,
#        [ 1.60127225e-04,  4.18852677e-05, -5.09294780e-04, ...,
#          4.94796885e-04, -9.88082016e-06, -6.25720637e-05],
#        [-5.99811190e-05,  1.39857006e-05, -6.57153853e-05, ...,
#         -9.88082016e-06,  9.13442533e-05,  1.70176379e-06],
#        [-7.06174014e-04, -5.51223200e-05, -1.06499219e-03, ...,
#         -6.25720637e-05,  1.70176379e-06,  1.59077391e-03]])]
# Mixing Coefficients (Weights): [0.99999998]
#
# Training GMM for class: elevator_shaft
#
# Final GMM Parameters for class elevator_shaft:
# Means (Centroids): [[9.46540122e-02 4.84363594e-04 2.50996709e-01 4.34282150e-03
#   1.85758510e-04 2.77030030e-02 0.00000000e+00 9.87855028e-04
#   1.02877986e-02 2.45565954e-02 2.88218973e-03 7.36665178e-04
#   5.53472941e-02 7.49252340e-03 2.60018734e-02 1.20035514e-01
#   6.26685902e-03 1.03673848e-02 1.69305100e-02 3.19724319e-02
#   1.79180306e-02 1.58153270e-03 1.50988943e-01 1.51469516e-02
#   1.31175803e-03 2.94070659e-02 3.80952373e-05 5.06576508e-04
#   2.14815262e-02 3.16734501e-02 2.79178061e-03 3.49221066e-02]]
# Covariances: [array([[ 7.71671249e-03,  3.41828562e-05,  1.04490908e-03, ...,
#          1.75555990e-04, -1.89254238e-04, -2.03727843e-03],
#        [ 3.41828562e-05,  6.29151137e-06, -5.95926901e-05, ...,
#         -1.27543801e-05, -1.34571773e-06, -1.10385057e-05],
#        [ 1.04490908e-03, -5.95926901e-05,  2.55656792e-02, ...,
#         -4.71893464e-04,  1.24688037e-05, -1.93610964e-03],
#        ...,
#        [ 1.75555990e-04, -1.27543801e-05, -4.71893464e-04, ...,
#          1.20981374e-03,  2.42844553e-05, -4.61699976e-04],
#        [-1.89254238e-04, -1.34571773e-06,  1.24688037e-05, ...,
#          2.42844553e-05,  5.31141683e-05,  7.02415572e-05],
#        [-2.03727843e-03, -1.10385057e-05, -1.93610964e-03, ...,
#         -4.61699976e-04,  7.02415572e-05,  2.72211885e-03]])]
# Mixing Coefficients (Weights): [0.99999998]

# %% [markdown]
# # Step 4 :Testing and Evaluation

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

# Classify new data points using trained GMM
def classify_gmm(x, gmm_models):
    likelihoods = {}
    for class_name, (means, covariances, weights) in gmm_models.items():
        likelihoods[class_name] = np.sum([weights[i] * gaussian_pdf(x, means[i], covariances[i]) for i in range(len(means))])
    return max(likelihoods, key=likelihoods.get)

def evaluate_gmm(test_features_path, gmm_models):
    label_dict = {'botanical_garden': 0, 'bus_interior': 1, 'elevator_shaft': 2}
    
    y_true = []
    y_pred = []
    
    for class_name in label_dict:
        class_label = label_dict[class_name]
        class_folder = os.path.join(test_features_path, class_name)
        test_features = np.vstack([np.load(os.path.join(class_folder, f)) for f in os.listdir(class_folder)])
        
        for feature in test_features:
            predicted_class = classify_gmm(feature, gmm_models)
            y_true.append(class_label)
            y_pred.append(label_dict[predicted_class])
    
    return np.array(y_true), np.array(y_pred)

def calculate_metrics(y_true, y_pred):
    label_names = ['botanical_garden', 'bus_interior', 'elevator_shaft']
    precision_per_class = precision_score(y_true, y_pred, average=None, zero_division=0)
    recall_per_class = recall_score(y_true, y_pred, average=None, zero_division=0)
    f1_per_class = f1_score(y_true, y_pred, average=None, zero_division=0)
    
    mean_precision = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    mean_recall = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    mean_f1 = f1_score(y_true, y_pred, average='weighted', zero_division=0)
    
    accuracy = np.mean(y_true == y_pred)
    conf_matrix = confusion_matrix(y_true, y_pred, labels=[0, 1, 2])
    
    print(f"Accuracy: {accuracy * 100:.2f}%")
    print("Confusion Matrix:")
    print(conf_matrix)
    
    print("\nClass-wise Precision, Recall, F1-score:")
    for i, class_name in enumerate(label_names):
        print(f"{class_name}:")
        print(f"  Precision: {precision_per_class[i]:.4f}")
        print(f"  Recall: {recall_per_class[i]:.4f}")
        print(f"  F1-Score: {f1_per_class[i]:.4f}")
    
    print("\nMean Precision, Recall, F1-Score (weighted):")
    print(f"  Mean Precision: {mean_precision:.4f}")
    print(f"  Mean Recall: {mean_recall:.4f}")
    print(f"  Mean F1-Score: {mean_f1:.4f}")

# Example usage
test_features_path = r'3-class-scene-image-dataset/output_test_features_bovw'
y_true, y_pred = evaluate_gmm(test_features_path, gmm_models)
calculate_metrics(y_true, y_pred)
# Out:
# Accuracy: 65.33%
# Confusion Matrix:
# [[43  2  5]
#  [10 20 20]
#  [ 7  8 35]]
#
# Class-wise Precision, Recall, F1-score:
# botanical_garden:
#   Precision: 0.7167
#   Recall: 0.8600
#   F1-Score: 0.7818
# bus_interior:
#   Precision: 0.6667
#   Recall: 0.4000
#   F1-Score: 0.5000
# elevator_shaft:
#   Precision: 0.5833
#   Recall: 0.7000
#   F1-Score: 0.6364
#
# Mean Precision, Recall, F1-Score (weighted):
#   Mean Precision: 0.6556
#   Mean Recall: 0.6533
#   Mean F1-Score: 0.6394
